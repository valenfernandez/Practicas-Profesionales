# %% [markdown]
# # EDA Dataset de Violencia de Genero
# ## Analisis exploratorio de datos usando la libreria spaCy

# %% [markdown]
# Se identificaron en el dataset aquellas celdas con frases relevantes (celdas no vacias, que tengan frases distintas a 'no_corresponde' y que no esten repetidas).
# Para trabajar con el dataset xlsx se crearon un par de funciones en un modulo que se llamó xl_text que pasa las celdas con la informacion a textos que pueden ser procesados con spacy.

# %%
# en archivo xl_text:

    
def excel_to_set(doc, first_cell, last_cell):
    """
    Esta funcion devuelve una lista con todas las frases unicas almacenadas en un grupo de celdas de un excel
    doc: string nombre del archivo excel a trabajar.
    first_cell: primera celda del rango a copiar.
    last_cell: ultima celda del rango a copiar
    """
    phrases = []
    excel_document = openpyxl.load_workbook(doc, data_only=True)
    first_sheet = excel_document.sheetnames[0]
    sheet = excel_document[first_sheet]
    for row in sheet[first_cell:last_cell]:
        for cell in row:
            if cell.value and cell.value != 'no_corresponde':  # si la celda tiene informacion
                cell_with_spaces = cell.value.replace('_', ' ')
                phrases.append(cell_with_spaces)
    return set(phrases)


def excel_to_text(doc, first_cell, last_cell):
    """ Esta funcion devuelve en forma de string los datos relevantes almacenados en un grupo de celdas de un excel
        doc: string nombre del archivo excel a trabajar.
        first_cell: primera celda del rango a copiar.
        last_cell: ultima celda del rango a copiar
        """
    phrases = excel_to_set(doc, first_cell, last_cell)
    text = ""
    for phrase in phrases:
        text += f'{phrase}\n'
    return text


def num_relevant_cells(doc, first_cell, last_cell):
    """Esta funcion escribe por pantalla estadisticas de el numero de celdas
    con informacion no nula en un rango de celdas de una columna en un excel

    doc: string nombre del archivo excel a trabajar.
    first_cell: primera celda del rango
    last_cell: ultima celda del rango
    """
    percentage = 0
    relevant_cells = len(excel_to_set(doc, first_cell, last_cell))
    total = int(last_cell[1:]) - int(first_cell[1:]) # solo funciona si trabajo en la misma columna. Sino usaria otro loop
    if total != 0:
        percentage = relevant_cells * 100 / total
    print(f'el numero total de celdas: {total} \n'
          f'el numero total de celdas con informacion unica: {relevant_cells}\n'
          f'eso es un %{percentage:.2f} de celdas con informacion')

# %% [markdown]
# En este caso se encontraron 337 celdas con frases unicas utiles para procesar:

# %%
from xl_text import num_relevant_cells

num_relevant_cells('set_de_datos_con_perspectiva_de_genero.xlsx', first_cell='S2', last_cell='S3827')
# Out:
# el numero total de celdas: 3825
# el numero total de celdas con informacion unica: 337
# eso es un %8.81 de celdas con informacion

# %% [markdown]
#    En primer lugar se analizaron estas frases encontradas en el dataset con el modelo preentrenado de spacy 'es_core_news_sm' (un modelo entrenado usando noticias).
#    - Se puede observar que este modelo logra indentificar de forma satisfactoria los part of speech tags (osea la categoria gramatical) y las dependencias (analisis sintactico de la relacion entre las palabras) de los tokens en cada frase.
#
#    Con este primer procesamiento observamos las frases encontradas y analizamos la estructura de las mismas, lo que es beneficioso para lograr una mejor interpretación de los datos.

# %%
import spacy
from xl_text import excel_to_set 

texts = list(excel_to_set('set_de_datos_con_perspectiva_de_genero.xlsx', first_cell='S2', last_cell='S3827'))
nlp = spacy.load("es_core_news_sm")
docs = [nlp(text) for text in texts]

print("tokens, su part-of-speech tag y dependency label:\n")
for doc in docs:
    print(f'\n{doc.text}')
    for token in doc:
        token_text = token.text
        token_pos = token.pos_
        token_dep = token.dep_
        print("{:<12}{:<10}{:<10}".format(token_text, token_pos, token_dep))
# Out:
# tokens, su part-of-speech tag y dependency label:
#
#
# hija de puta te mato te mato a vos a tu macho y a quien se meta me importa tres huevos la policia no me interesa ir preso
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# te          PRON      obj
# mato        VERB      nsubj
# te          PRON      obj
# mato        VERB      ROOT
# a           ADP       case
# vos         PROPN     obl
# a           ADP       case
# tu          DET       det
# macho       INTJ      obj
# y           CCONJ     cc
# a           ADP       case
# quien       PRON      obj
# se          PRON      obj
# meta        VERB      conj
# me          PRON      obj
# importa     VERB      advcl
# tres        NUM       nummod
# huevos      NOUN      nsubj
# la          DET       det
# policia     NOUN      nsubj
# no          ADV       advmod
# me          PRON      obj
# interesa    VERB      conj
# ir          VERB      csubj
# preso       ADJ       obj
#
# sos una puta todo el mundo va a saber lo que sos la vas a pagar
# sos         VERB      ROOT
# una         DET       det
# puta        NOUN      nsubj
# todo        DET       det
# el          DET       det
# mundo       NOUN      nsubj
# va          AUX       aux
# a           ADP       mark
# saber       VERB      conj
# lo          PRON      det
# que         SCONJ     nsubj
# sos         VERB      ccomp
# la          DET       det
# vas         NOUN      obj
# a           ADP       mark
# pagar       VERB      xcomp
#
# con mi plata hago lo que quiero
# con         ADP       case
# mi          DET       det
# plata       NOUN      obl
# hago        VERB      ROOT
# lo          PRON      det
# que         SCONJ     obj
# quiero      VERB      ccomp
#
# andate a la concha de tu madre, hija de puta  ya te voy a enganchar asi como vos me estas cagando la vida yo te la voy a cagar a vos y te voy a pegar donde mas te duele te voy a matar la concha bien de tu madre te voy a pegar donde mas te duele ya te voy a enganchar y te voy a cagar a palos no me importa nada si no estas conmigo me mato
# andate      PROPN     nsubj
# a           ADP       case
# la          DET       det
# concha      NOUN      obj
# de          ADP       case
# tu          DET       nmod
# madre       PROPN     flat
# ,           PUNCT     punct
# hija        NOUN      appos
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# ya          ADV       advmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# enganchar   VERB      advcl
# asi         ADV       advmod
# como        SCONJ     mark
# vos         ADJ       obl
# me          PRON      obj
# estas       DET       aux
# cagando     VERB      advcl
# la          DET       det
# vida        NOUN      obj
# yo          PRON      nsubj
# te          PRON      iobj
# la          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cagar       VERB      xcomp
# a           ADP       case
# vos         PROPN     obj
# y           CCONJ     cc
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# pegar       VERB      conj
# donde       PRON      mark
# mas         CCONJ     advmod
# te          PRON      obj
# duele       VERB      ccomp
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# la          DET       det
# concha      NOUN      obj
# bien        ADV       advmod
# de          ADP       case
# tu          DET       det
# madre       NOUN      obj
# te          PRON      iobj
# voy         AUX       aux
# a           ADP       mark
# pegar       VERB      xcomp
# donde       PRON      mark
# mas         CCONJ     nsubj
# te          PRON      obj
# duele       VERB      ccomp
# ya          ADV       advmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# enganchar   VERB      xcomp
# y           CCONJ     cc
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cagar       VERB      conj
# a           ADP       case
# palos       NOUN      obj
# no          ADV       advmod
# me          PRON      obj
# importa     VERB      ROOT
# nada        PRON      nsubj
# si          SCONJ     mark
# no          ADV       advmod
# estas       DET       det
# conmigo     VERB      nsubj
# me          PRON      obj
# mato        VERB      advcl
#
# no denuncies  sabes lo que se te viene
# no          ADV       advmod
# denuncies   VERB      ROOT
#             SPACE
# sabes       VERB      advcl
# lo          PRON      det
# que         SCONJ     nsubj
# se          PRON      expl:pass
# te          PRON      obj
# viene       VERB      ccomp
#
# puta de mierda, vos seguro estas con mi sobrino  vos le abris las piernas a cualquiera
# puta        NOUN      nsubj
# de          ADP       case
# mierda      NOUN      nmod
# ,           PUNCT     punct
# vos         ADJ       amod
# seguro      ADV       amod
# estas       DET       det
# con         ADP       case
# mi          DET       det
# sobrino     NOUN      nmod
#             SPACE
# vos         ADJ       appos
# le          PRON      obj
# abris       VERB      ROOT
# las         DET       det
# piernas     NOUN      obj
# a           ADP       case
# cualquiera  PRON      nmod
#
# vos tenes la culpa de todo tengo ganas de romperte la cabeza
# vos         ADJ       amod
# tenes       NOUN      ROOT
# la          DET       det
# culpa       NOUN      obj
# de          ADP       case
# todo        DET       nmod
# tengo       VERB      advcl
# ganas       NOUN      obj
# de          ADP       case
# romperte    NOUN      nmod
# la          DET       det
# cabeza      NOUN      appos
#
# sos una negra de mierda, no voy a
# parar de molestarte hasta que te mudes de aca negra mierda te voy a matar
# y a vos pelado que decis que me la vas a dar anda cagala a palos qué lloras le tenes miedo a esa negra de mierda
# sos         VERB      advcl
# una         DET       det
# negra       NOUN      nsubj
# de          ADP       case
# mierda      NOUN      nmod
# ,           PUNCT     punct
# no          ADV       advmod
# voy         VERB      ROOT
# a           ADP       mark
#
#            SPACE
# parar       VERB      xcomp
# de          ADP       case
# molestarte  NOUN      obj
# hasta       ADP       mark
# que         SCONJ     mark
# te          PRON      obj
# mudes       NOUN      advcl
# de          ADP       case
# aca         NOUN      nmod
# negra       ADJ       amod
# mierda      ADJ       nsubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      advcl
#
#            SPACE
# y           CCONJ     cc
# a           ADP       case
# vos         PROPN     amod
# pelado      INTJ      conj
# que         SCONJ     mark
# decis       VERB      acl
# que         SCONJ     mark
# me          PRON      iobj
# la          PRON      obj
# vas         NOUN      ccomp
# a           ADP       mark
# dar         VERB      xcomp
# anda        NOUN      amod
# cagala      NOUN      obj
# a           ADP       case
# palos       NOUN      obj
# qué         DET       det
# lloras      NOUN      nsubj
# le          PRON      obj
# tenes       NOUN      ccomp
# miedo       NOUN      obj
# a           ADP       case
# esa         DET       det
# negra       NOUN      nmod
# de          ADP       case
# mierda      NOUN      nmod
#
# no me importa nada te voy a matar  puta de mierda  trola  te voy a arruinar muerto o preso no me importa no te mereces a mi hijo
# no          ADV       advmod
# me          PRON      obj
# importa     VERB      ROOT
# nada        PRON      nsubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      csubj
#             SPACE
# puta        NOUN      obj
# de          ADP       case
# mierda      ADJ       nmod
#             SPACE
# trola       VERB      appos
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# arruinar    VERB      csubj
# muerto      ADJ       obj
# o           CCONJ     cc
# preso       ADJ       conj
# no          ADV       advmod
# me          PRON      obj
# importa     VERB      advcl
# no          ADV       advmod
# te          PRON      obj
# mereces     VERB      csubj
# a           ADP       case
# mi          DET       det
# hijo        NOUN      obj
#
# sino venis conmigo te vas a morir por coronavirus
# sino        CCONJ     advmod
# venis       PROPN     nsubj
# conmigo     PRON      flat
# te          PRON      iobj
# vas         VERB      ROOT
# a           ADP       mark
# morir       VERB      xcomp
# por         ADP       case
# coronavirus NOUN      obl
#
# zorra   te voy a grabar para mandar a alguien que te mate   puta   te voy a mandar a matar
# zorra       VERB      nsubj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# grabar      VERB      ROOT
# para        ADP       mark
# mandar      VERB      advcl
# a           ADP       case
# alguien     PRON      obj
# que         SCONJ     nsubj
# te          PRON      obj
# mate        VERB      acl
#             SPACE
# puta        NOUN      obj
#             SPACE
# te          PRON      iobj
# voy         AUX       aux
# a           ADP       mark
# mandar      VERB      xcomp
# a           ADP       mark
# matar       VERB      xcomp
#
# no te metas mas conmigo   no vas a ver mas a las nenas   ya se donde te mudaste
# no          ADV       advmod
# te          PRON      obj
# metas       VERB      ROOT
# mas         CCONJ     advmod
# conmigo     PRON      nsubj
#             SPACE
# no          ADV       advmod
# vas         VERB      conj
# a           ADP       mark
# ver         VERB      xcomp
# mas         ADV       obj
# a           ADP       case
# las         DET       det
# nenas       NOUN      obj
#             SPACE
# ya          ADV       advmod
# se          PRON      obj
# donde       PRON      obl
# te          PRON      obj
# mudaste     VERB      advcl
#
# no vas a estar con nadie  no te voy a dejar estar con nadie vos sos mia
# no          ADV       advmod
# vas         VERB      ROOT
# a           ADP       mark
# estar       VERB      xcomp
# con         ADP       case
# nadie       PRON      obl
#             SPACE
# no          ADV       advmod
# te          PRON      iobj
# voy         AUX       aux
# a           ADP       mark
# dejar       VERB      conj
# estar       VERB      xcomp
# con         ADP       case
# nadie       PRON      obl
# vos         ADJ       amod
# sos         VERB      det
# mia         NOUN      xcomp
#
# te voy a cagar a trompadas infeliz no servis para nada me das asco nunca vas a lograr nada
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cagar       VERB      ROOT
# a           ADP       case
# trompadas   NOUN      obj
# infeliz     PROPN     amod
# no          ADV       advmod
# servis      VERB      advcl
# para        ADP       case
# nada        INTJ      obl
# me          PRON      obj
# das         VERB      conj
# asco        NOUN      obj
# nunca       ADV       advmod
# vas         VERB      advcl
# a           ADP       mark
# lograr      VERB      xcomp
# nada        PRON      obj
#
# te voy a matar conchuda ya no te aguanto hija de puta
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      csubj
# conchuda    NOUN      obj
# ya          ADV       advmod
# no          ADV       advmod
# te          PRON      obj
# aguanto     VERB      ROOT
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      nmod
#
# puta te voy a matar no servis para nada
# puta        NOUN      nsubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# no          ADV       advmod
# servis      VERB      obj
# para        ADP       case
# nada        PRON      obl
#
# te voy a matar   levanta la causa sino te voy a matar
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
#             SPACE
# levanta     VERB      advcl
# la          DET       det
# causa       NOUN      obj
# sino        CCONJ     cc
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      conj
#
# me mato o te mato
# me          PRON      obj
# mato        VERB      ROOT
# o           CCONJ     cc
# te          PRON      obj
# mato        VERB      conj
#
# despues no queres que te golpee te vas de aca pero los chicos se quedan
# despues     NOUN      nsubj
# no          ADV       advmod
# queres      VERB      ROOT
# que         SCONJ     mark
# te          PRON      obj
# golpee      VERB      ccomp
# te          PRON      obj
# vas         VERB      ccomp
# de          ADP       case
# aca         NOUN      obj
# pero        CCONJ     cc
# los         DET       det
# chicos      NOUN      nsubj
# se          PRON      obj
# quedan      AUX       conj
#
# me la vas a pagar te voy a buscar te voy a encontrar
# me          PRON      iobj
# la          DET       obj
# vas         NOUN      csubj
# a           ADP       mark
# pagar       VERB      xcomp
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# buscar      VERB      xcomp
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# encontrar   VERB      ROOT
#
# puta   me arruinaste la vida
# puta        NOUN      nsubj
#             SPACE
# me          PRON      obj
# arruinaste  VERB      ROOT
# la          DET       det
# vida        NOUN      obj
#
# porque sos asi vos no eras asi   te voy a sacar a los chicos  vos te vas con el   lo voy a matar a el   te voy a matar
# porque      SCONJ     mark
# sos         DET       nsubj
# asi         ADV       advmod
# vos         ADJ       amod
# no          ADV       advmod
# eras        AUX       advcl
# asi         ADV       advmod
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      csubj
# a           ADP       case
# los         DET       det
# chicos      NOUN      obj
#             SPACE
# vos         ADJ       obj
# te          PRON      obj
# vas         VERB      ROOT
# con         ADP       mark
# el          DET       det
#             SPACE
# lo          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      advcl
# a           ADP       mark
# el          DET       det
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
#
# te voy a hacer algo que te va a doler
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      ROOT
# algo        PRON      obj
# que         SCONJ     mark
# te          PRON      obj
# va          AUX       aux
# a           ADP       case
# doler       VERB      acl
#
# puta   perra   mantenida
# puta        NOUN      nsubj
#             SPACE
# perra       PROPN     ROOT
#             SPACE
# mantenida   ADJ       obj
#
# sos una mala madre   te voy a sacar a tus hijos
# sos         VERB      det
# una         DET       det
# mala        ADJ       amod
# madre       NOUN      nsubj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      ROOT
# a           ADP       case
# tus         DET       det
# hijos       NOUN      obj
#
# te voy a hacer quilombo en tu casa y en tu trabajo   vieja de mierda   llama a la policia aca espero   hija de puta   te voy a hacer echar del trabajo
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      ROOT
# quilombo    NOUN      obj
# en          ADP       case
# tu          DET       det
# casa        NOUN      obl
# y           CCONJ     cc
# en          ADP       case
# tu          DET       det
# trabajo     NOUN      obl
#             SPACE
# vieja       ADJ       amod
# de          ADP       case
# mierda      NOUN      nmod
#             SPACE
# llama       VERB      conj
# a           ADP       case
# la          DET       det
# policia     NOUN      obj
# aca         PROPN     flat
# espero      VERB      advcl
#             SPACE
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      obj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      advcl
# echar       VERB      xcomp
# del         ADP       case
# trabajo     NOUN      obl
#
# sos una puta   me la vas a pagar   te voy a matar   estas con otro
# sos         VERB      iobj
# una         DET       det
# puta        NOUN      nsubj
#             SPACE
# me          PRON      iobj
# la          PRON      obj
# vas         NOUN      csubj
# a           ADP       mark
# pagar       VERB      xcomp
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
#             SPACE
# estas       DET       obj
# con         ADP       case
# otro        PRON      obl
#
# hoy te vas de esta casa   con la policia no me vas a asustar
# hoy         ADV       advmod
# te          PRON      obj
# vas         VERB      ROOT
# de          ADP       case
# esta        DET       det
# casa        NOUN      obl
#             SPACE
# con         ADP       case
# la          DET       det
# policia     NOUN      obl
# no          ADV       advmod
# me          PRON      iobj
# vas         VERB      conj
# a           ADP       mark
# asustar     VERB      xcomp
#
# no vas a poder caminar tranquila
# no          ADV       advmod
# vas         VERB      ROOT
# a           ADP       mark
# poder       VERB      aux
# caminar     VERB      xcomp
# tranquila   NOUN      obj
#
# hija de puta   mañana no vas a estar viva
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# mañana      ADV       advmod
# no          ADV       advmod
# vas         VERB      ROOT
# a           ADP       case
# estar       VERB      cop
# viva        ADJ       xcomp
#
# gorda lechona vas a vivir toda tu vida asi te falta mucho para bajar de peso
# gorda       PROPN     nsubj
# lechona     PROPN     flat
# vas         ADJ       csubj
# a           ADP       mark
# vivir       VERB      xcomp
# toda        DET       det
# tu          DET       det
# vida        NOUN      obj
# asi         ADV       advmod
# te          PRON      obj
# falta       VERB      ROOT
# mucho       ADV       advmod
# para        ADP       mark
# bajar       VERB      advcl
# de          ADP       case
# peso        NOUN      obl
#
# sos una puta una vieja maldita te voy a robar te voy a cagar a palos
# sos         VERB      cop
# una         DET       det
# puta        NOUN      iobj
# una         DET       det
# vieja       NOUN      amod
# maldita     ADJ       amod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# robar       VERB      ROOT
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cagar       VERB      xcomp
# a           ADP       case
# palos       NOUN      obj
#
# no me rompas las pelotas porque me voy a ir
# no          ADV       advmod
# me          PRON      obj
# rompas      VERB      ROOT
# las         DET       det
# pelotas     NOUN      nsubj
# porque      SCONJ     mark
# me          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# ir          VERB      advcl
#
# puta de mierda   traes a tus machos aca te los voy a terminar matando   hija de puta   te voy a matar y despues me mato yo   con quien estabas   callate  te voy a romper la boca
# puta        NOUN      nsubj
# de          ADP       case
# mierda      NOUN      nmod
#             SPACE
# traes       AUX       advcl
# a           ADP       case
# tus         DET       det
# machos      NOUN      obj
# aca         NOUN      appos
# te          PRON      obj
# los         PRON      obj
# voy         AUX       aux
# a           ADP       mark
# terminar    VERB      xcomp
# matando     VERB      xcomp
#             SPACE
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      obl
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# y           CCONJ     cc
# despues     NOUN      conj
# me          PRON      obj
# mato        VERB      ROOT
# yo          PRON      nsubj
#             SPACE
# con         ADP       case
# quien       PRON      obl
# estabas     VERB      acl
#             SPACE
# callate     VERB      obj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# romper      VERB      xcomp
# la          DET       det
# boca        NOUN      obj
#
# esta quiere que me vaya quiere traer a sus machos
# esta        DET       nsubj
# quiere      NOUN      ROOT
# que         SCONJ     mark
# me          PRON      obj
# vaya        VERB      aux
# quiere      VERB      ccomp
# traer       VERB      xcomp
# a           ADP       case
# sus         DET       det
# machos      NOUN      obj
#
# hija de puta te voy a matar eso es lo que vos queres  te voy a matar hija de puta
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      csubj
# eso         PRON      obj
# es          AUX       ROOT
# lo          PRON      det
# que         SCONJ     nsubj
# vos         ADJ       nsubj
# queres      NOUN      obj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ccomp
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      nmod
#
# entregame a la nena   te voy a hacer desaparecer   te voy a matar
# entregame   ADJ       advmod
# a           ADP       case
# la          DET       det
# nena        NOUN      obl
#             SPACE
# te          PRON      iobj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      csubj
# desaparecer VERB      xcomp
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
#
# te voy a sacar al nene  te voy a matar
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      ROOT
# al          ADP       case
# nene        VERB      obl
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
#
# la vas a pagar vas a llorar no me dejas otra opcion si no me contestas voy a ir a casa  ya vas a ver
# la          DET       det
# vas         NOUN      nsubj
# a           ADP       mark
# pagar       VERB      acl
# vas         NOUN      advcl
# a           ADP       mark
# llorar      VERB      xcomp
# no          ADV       advmod
# me          PRON      obj
# dejas       VERB      ROOT
# otra        DET       det
# opcion      PROPN     nsubj
# si          SCONJ     mark
# no          ADV       advmod
# me          PRON      obj
# contestas   VERB      advcl
# voy         AUX       aux
# a           ADP       mark
# ir          VERB      csubj
# a           ADP       case
# casa        NOUN      obl
#             SPACE
# ya          ADV       advmod
# vas         VERB      conj
# a           ADP       mark
# ver         VERB      xcomp
#             SPACE
#
# hija de puta  te vas a arrepentir toda tu vida  te vas a arrepentir asi son ustedes que inventan  asi son ustedes
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# te          PRON      iobj
# vas         VERB      csubj
# a           ADP       mark
# arrepentir  VERB      xcomp
# toda        DET       det
# tu          DET       det
# vida        NOUN      obj
#             SPACE
# te          PRON      obj
# vas         VERB      advcl
# a           ADP       mark
# arrepentir  VERB      xcomp
# asi         ADV       obj
# son         VERB      cop
# ustedes     PRON      advcl
# que         SCONJ     nsubj
# inventan    AUX       acl
#             SPACE
# asi         ADV       obj
# son         VERB      cop
# ustedes     PRON      ROOT
#
# puta de mierda te voy a matar te voy a acuchillar
# puta        NOUN      nsubj
# de          ADP       case
# mierda      NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      csubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# acuchillar  VERB      ROOT
#
# tene cuidado con la nena   mira que puede desaparecer   te la pueden violar
# tene        VERB      ccomp
# cuidado     ADJ       obj
# con         ADP       case
# la          DET       det
# nena        NOUN      obl
#             SPACE
# mira        VERB      ccomp
# que         SCONJ     mark
# puede       AUX       aux
# desaparecer VERB      xcomp
#             SPACE
# te          PRON      iobj
# la          PRON      obj
# pueden      VERB      aux
# violar      VERB      ROOT
#
# me la vas a pagar te voy a buscar  te voy a encontar
# me          PRON      iobj
# la          DET       obj
# vas         NOUN      csubj
# a           ADP       mark
# pagar       VERB      xcomp
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# buscar      VERB      xcomp
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# encontar    VERB      ROOT
#
# te gusta mi pija amor
# te          PRON      obj
# gusta       VERB      ROOT
# mi          DET       det
# pija        NOUN      nsubj
# amor        NOUN      appos
#
# te voy a matar te voy a desfigurar toda te voy a abrir la panza me voy a llevar a la nena
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# desfigurar  VERB      xcomp
# toda        DET       det
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# abrir       VERB      xcomp
# la          DET       det
# panza       NOUN      obj
# me          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# llevar      VERB      advcl
# a           ADP       case
# la          DET       det
# nena        NOUN      obj
#
# estupida tarada yo te lo prometo que te hago la vida imposible
# estupida    ADJ       advcl
# tarada      ADJ       flat
# yo          PRON      nsubj
# te          PRON      iobj
# lo          PRON      obj
# prometo     VERB      ROOT
# que         SCONJ     mark
# te          PRON      obj
# hago        VERB      ccomp
# la          DET       det
# vida        NOUN      obj
# imposible   ADJ       amod
#
# hija de puta   te voy a clavar un cuchillo
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# clavar      VERB      ROOT
# un          DET       det
# cuchillo    NOUN      obj
#
# de aca viva no salis
# de          ADP       case
# aca         PROPN     obj
# viva        ADJ       amod
# no          ADV       advmod
# salis       ADJ       ROOT
#
# voy a pagar para que te maten no me voy a ensuciar las manos
# voy         AUX       aux
# a           ADP       mark
# pagar       VERB      ROOT
# para        ADP       mark
# que         SCONJ     mark
# te          PRON      obj
# maten       AUX       advcl
# no          ADV       advmod
# me          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# ensuciar    VERB      csubj
# las         DET       det
# manos       NOUN      obj
#
# te voy a matar cuando te vea con otro
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# cuando      SCONJ     mark
# te          PRON      obj
# vea         VERB      advcl
# con         ADP       case
# otro        PRON      obl
#
# por que me sacaste a mis hijas   te voy a matar a mi no me importa ningun juez
# por         ADP       case
# que         SCONJ     obl
# me          PRON      obj
# sacaste     VERB      ccomp
# a           ADP       case
# mis         DET       det
# hijas       NOUN      obj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      csubj
# a           ADP       case
# mi          DET       obj
# no          ADV       advmod
# me          PRON      obj
# importa     VERB      ROOT
# ningun      NOUN      nsubj
# juez        NOUN      amod
#
# no servis para nada
# no          ADV       advmod
# servis      VERB      ROOT
# para        ADP       case
# nada        PRON      obl
#
# hija de puta inutil
# hija        NOUN      ROOT
# de          ADP       case
# puta        NOUN      nmod
# inutil      ADJ       amod
#
# puta de mierda
# puta        NOUN      ROOT
# de          ADP       case
# mierda      NOUN      nmod
#
# callate la concha de tu madre vos y la pendeja de mierda me tienen podrido las voy a matar
# callate     NOUN      nsubj
# la          DET       det
# concha      NOUN      obj
# de          ADP       case
# tu          DET       det
# madre       PROPN     nmod
# vos         PROPN     amod
# y           CCONJ     cc
# la          DET       det
# pendeja     NOUN      conj
# de          ADP       case
# mierda      NOUN      nmod
# me          PRON      obj
# tienen      AUX       ROOT
# podrido     ADJ       obj
# las         DET       obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
#
# puta perra
# puta        NOUN      ROOT
# perra       ADJ       flat
#
# te voy a matar perra  puta de esta no te salvas   te voy a sacar el bebe
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# perra       INTJ      obj
#             SPACE
# puta        ADJ       obj
# de          ADP       case
# esta        PRON      nmod
# no          ADV       advmod
# te          PRON      obj
# salvas      VERB      conj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      advcl
# el          DET       det
# bebe        NOUN      obj
#
# ahora te voy a dejar yo marcas en la boca  a ver hija de puta estas depilada  a ver si estas dilatada
# ahora       ADV       advmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# dejar       VERB      ROOT
# yo          PRON      nsubj
# marcas      NOUN      amod
# en          ADP       case
# la          DET       det
# boca        NOUN      obl
#             SPACE
# a           ADP       mark
# ver         VERB      xcomp
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      nmod
# estas       DET       det
# depilada    ADJ       appos
#             SPACE
# a           ADP       mark
# ver         VERB      xcomp
# si          SCONJ     mark
# estas       DET       det
# dilatada    ADJ       obj
#
# quiero a mis hijos ya te voy a hacer la vida imposible tengo que contarle a tu jefe lo que hiciste en trabajos anteriores
# quiero      VERB      ROOT
# a           ADP       case
# mis         DET       det
# hijos       NOUN      iobj
# ya          ADV       advmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      xcomp
# la          DET       det
# vida        NOUN      obj
# imposible   ADJ       amod
# tengo       VERB      ccomp
# que         SCONJ     cc
# contarle    VERB      conj
# a           ADP       case
# tu          DET       det
# jefe        NOUN      obj
# lo          PRON      det
# que         SCONJ     obj
# hiciste     VERB      ccomp
# en          ADP       case
# trabajos    NOUN      obl
# anteriores  ADJ       amod
#
# despues no quiero reclamos
# despues     NOUN      nsubj
# no          ADV       advmod
# quiero      VERB      ROOT
# reclamos    VERB      obj
#
# puta no vas a salir te cago la noche vos sos mi sirvienta
# puta        NOUN      nsubj
# no          ADV       advmod
# vas         VERB      ROOT
# a           ADP       mark
# salir       VERB      xcomp
# te          PRON      obj
# cago        VERB      advcl
# la          DET       det
# noche       NOUN      obl
# vos         ADJ       amod
# sos         PROPN     advcl
# mi          DET       det
# sirvienta   VERB      obj
#
# mentirosa   nunca te pegue   fuiste vos   me denunciaste   ya van a ver quien soy   se las voy a dar
# mentirosa   ADJ       nsubj
#             SPACE
# nunca       ADV       advmod
# te          PRON      obj
# pegue       VERB      ROOT
#             SPACE
# fuiste      VERB      advcl
# vos         ADJ       flat
#             SPACE
# me          PRON      obj
# denunciaste VERB      advcl
#             SPACE
# ya          ADV       advmod
# van         VERB      aux
# a           ADP       mark
# ver         VERB      advcl
# quien       PRON      nsubj
# soy         AUX       aux
#             SPACE
# se          PRON      iobj
# las         PRON      obj
# voy         AUX       aux
# a           ADP       mark
# dar         VERB      xcomp
#
# vos sos mia
# vos         ADJ       ROOT
# sos         PROPN     flat
# mia         NOUN      compound
#
# dame a mi hija   te tiro la puerta abajo
# dame        VERB      csubj
# a           ADP       case
# mi          DET       det
# hija        NOUN      obj
#             SPACE
# te          PRON      obj
# tiro        VERB      ROOT
# la          DET       det
# puerta      NOUN      obj
# abajo       ADV       advmod
#
# haganse cargo de esta mujer No te hagas la viva yéndote temprano del trabajo Yo se donde vivís y se todo tu recorrido
# haganse     ADP       amod
# cargo       NOUN      obl
# de          ADP       case
# esta        DET       det
# mujer       NOUN      nmod
# No          ADV       advmod
# te          PRON      obj
# hagas       VERB      ROOT
# la          DET       det
# viva        NOUN      amod
# yéndote     PROPN     obj
# temprano    ADV       amod
# del         ADP       case
# trabajo     NOUN      nmod
# Yo          PRON      appos
# se          PRON      mark
# donde       PRON      obl
# vivís       NOUN      advcl
# y           CCONJ     cc
# se          PRON      obj
# todo        PRON      conj
# tu          DET       det
# recorrido   NOUN      nsubj
#
# tu vas a estar bien muerta te voy a arruinar te voy a matar
# tu          DET       det
# vas         INTJ      iobj
# a           ADP       case
# estar       VERB      cop
# bien        ADV       advmod
# muerta      ADJ       acl
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# arruinar    VERB      advcl
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
#
# ya vas a ver me la vas a pagar
# ya          ADV       advmod
# vas         VERB      csubj
# a           ADP       mark
# ver         VERB      xcomp
# me          PRON      iobj
# la          DET       obj
# vas         NOUN      ROOT
# a           ADP       mark
# pagar       VERB      xcomp
#
# te voy a quemar la casa   si haces la denuncia te mato   te voy a matar a vos y a tus hijos
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# quemar      VERB      ROOT
# la          DET       det
# casa        NOUN      obj
#             SPACE
# si          SCONJ     mark
# haces       VERB      advcl
# la          DET       det
# denuncia    NOUN      obj
# te          PRON      obj
# mato        VERB      advcl
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# a           ADP       case
# vos         PROPN     obj
# y           CCONJ     cc
# a           ADP       case
# tus         DET       det
# hijos       NOUN      conj
#
# hija de puta te voy a matar
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
#
# trola   puta   con razon tu familia no te quiere   hija de puta   me voy a suicidar   es tu culpa
# trola       VERB      nsubj
#             SPACE
# puta        NOUN      obj
#             SPACE
# con         ADP       case
# razon       PROPN     obl
# tu          DET       det
# familia     NOUN      nsubj
# no          ADV       advmod
# te          PRON      obj
# quiere      VERB      csubj
#             SPACE
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      obj
#             SPACE
# me          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# suicidar    VERB      advcl
#             SPACE
# es          AUX       cop
# tu          DET       det
# culpa       NOUN      ROOT
#
# dame el celular te voy a romper toda te voy a romper la cabeza me voy a ir pero te voy a romper toda
# dame        VERB      csubj
# el          DET       det
# celular     NOUN      nsubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# romper      VERB      csubj
# toda        DET       obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# romper      VERB      xcomp
# la          DET       det
# cabeza      NOUN      obj
# me          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# ir          VERB      ROOT
# pero        CCONJ     cc
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# romper      VERB      conj
# toda        DET       obj
#
# sos una enferma  hija de mil puta   te vas a morir en el infierno
# sos         VERB      ROOT
# una         DET       det
# enferma     NOUN      nsubj
#             SPACE
# hija        NOUN      nsubj
# de          ADP       case
# mil         NUM       nummod
# puta        NOUN      nmod
#             SPACE
# te          PRON      iobj
# vas         VERB      conj
# a           ADP       mark
# morir       VERB      xcomp
# en          ADP       case
# el          DET       det
# infierno    NOUN      obl
#
# no me importa nada  te voy a matar  puta de mierda  trola  te voy a arruinar  muerto o preso no me importa  no te mereces a mi hijo
# no          ADV       advmod
# me          PRON      obj
# importa     VERB      ROOT
# nada        PRON      nsubj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      csubj
#             SPACE
# puta        NOUN      obj
# de          ADP       case
# mierda      ADJ       nmod
#             SPACE
# trola       VERB      appos
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# arruinar    VERB      xcomp
#             SPACE
# muerto      ADJ       obj
# o           CCONJ     cc
# preso       ADJ       conj
# no          ADV       advmod
# me          PRON      obj
# importa     VERB      conj
#             SPACE
# no          ADV       advmod
# te          PRON      obj
# mereces     VERB      advcl
# a           ADP       case
# mi          DET       det
# hijo        NOUN      obj
#
# hija de mil puta te voy a sacar a la nena te voy a echar a la mierda te voy a matar
# hija        NOUN      nsubj
# de          ADP       case
# mil         NUM       nummod
# puta        NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      csubj
# a           ADP       case
# la          DET       det
# nena        NOUN      obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# echar       VERB      xcomp
# a           ADP       case
# la          DET       det
# mierda      NOUN      obl
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
#
# hijas de puta a tu mama la voy a matar
# hijas       NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# a           ADP       case
# tu          INTJ      det
# mama        INTJ      nmod
# la          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
#
# te voy a matar a vos voy a matar al negro de mierda ese que tenes con vos  hija de puta
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# a           ADP       case
# vos         PROPN     obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# al          ADP       case
# negro       NOUN      obl
# de          ADP       case
# mierda      NOUN      nmod
# ese         DET       det
# que         SCONJ     nsubj
# tenes       NOUN      ccomp
# con         ADP       case
# vos         ADJ       obl
#             SPACE
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      nmod
#
# sos una hija de puta  yo te ayude un monton que no te vea con nadie por aca porque lo voy a matar
# sos         VERB      obl
# una         DET       det
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# yo          PRON      nsubj
# te          PRON      obj
# ayude       VERB      ROOT
# un          DET       det
# monton      NOUN      obj
# que         SCONJ     nsubj
# ...
# te          PRON      obj
# mato        VERB      acl
# perra       PROPN     obj
#
# sos una conchuda   no te voy a dar plata   no me rompas mas las pelotas   pensa dos veces antes de decirme que no
# sos         VERB      nmod
# una         DET       det
# conchuda    NOUN      obj
#             SPACE
# no          ADV       advmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# dar         VERB      csubj
# plata       NOUN      obj
#             SPACE
# no          ADV       advmod
# me          PRON      obj
# rompas      VERB      ROOT
# mas         ADV       advmod
# las         DET       det
# pelotas     NOUN      nsubj
#             SPACE
# pensa       VERB      advcl
# dos         NUM       nummod
# veces       NOUN      obl
# antes       ADV       advmod
# de          ADP       mark
# decirme     VERB      advcl
# que         SCONJ     mark
# no          ADV       advmod
#
# te voy a quemar la casa si haces la denuncia te mato
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# quemar      VERB      ROOT
# la          DET       det
# casa        NOUN      obj
# si          SCONJ     mark
# haces       VERB      advcl
# la          DET       det
# denuncia    NOUN      obj
# te          PRON      obj
# mato        VERB      advcl
#
# hija de puta   puta de mierda   no te salva ni tu mama
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# puta        NOUN      amod
# de          ADP       case
# mierda      NOUN      nmod
#             SPACE
# no          ADV       advmod
# te          PRON      obj
# salva       VERB      ROOT
# ni          CCONJ     cc
# tu          DET       det
# mama        NOUN      obj
#
# puta ahi estan tus macho
# puta        NOUN      nsubj
# ahi         PROPN     flat
# estan       AUX       ROOT
# tus         SCONJ     det
# macho       VERB      obj
#
# hija de puta puta de mierda te voy a sacar a los hijos te voy a matar sino me das a mis hijos te voy a matar me las voy a cobrar todas las que me hiciste yo sin mis hijos no me voy a ir de esta casa  antes de irme te mato segui haciendo denuncias que asi te va a ir
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# puta        ADJ       amod
# de          ADP       case
# mierda      NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      ROOT
# a           ADP       case
# los         DET       det
# hijos       NOUN      obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# sino        CCONJ     cc
# me          PRON      obj
# das         VERB      conj
# a           ADP       case
# mis         DET       det
# hijos       NOUN      obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# me          PRON      obj
# las         PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cobrar      VERB      xcomp
# todas       DET       det
# las         DET       det
# que         SCONJ     obj
# me          PRON      obj
# hiciste     VERB      ccomp
# yo          PRON      nsubj
# sin         ADP       case
# mis         DET       det
# hijos       NOUN      obl
# no          ADV       advmod
# me          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# ir          VERB      conj
# de          ADP       case
# esta        DET       det
# casa        NOUN      obl
#             SPACE
# antes       ADV       advmod
# de          ADP       mark
# irme        VERB      advcl
# te          PRON      obj
# mato        VERB      ccomp
# segui       VERB      advcl
# haciendo    VERB      xcomp
# denuncias   NOUN      obj
# que         SCONJ     mark
# asi         ADV       advmod
# te          PRON      obj
# va          AUX       aux
# a           ADP       mark
# ir          VERB      acl
#
# no te hagas la viva que sabemos tus horarios y que vivis aca   te hago un monton de hijos   te parto en ocho   ya te voy a agarrar   te voy a hacer mierda
# no          ADV       advmod
# te          PRON      obj
# hagas       VERB      ROOT
# la          DET       det
# viva        NOUN      obj
# que         SCONJ     obj
# sabemos     VERB      acl
# tus         DET       det
# horarios    NOUN      obj
# y           CCONJ     cc
# que         SCONJ     mark
# vivis       PROPN     nsubj
# aca         VERB      flat
#             SPACE
# te          PRON      obj
# hago        VERB      conj
# un          DET       det
# monton      NOUN      obj
# de          ADP       case
# hijos       NOUN      nmod
#             SPACE
# te          PRON      obj
# parto       VERB      advcl
# en          ADP       case
# ocho        NUM       nummod
#             SPACE
# ya          ADV       advmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# agarrar     VERB      advcl
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      advcl
# mierda      NOUN      obj
#
# hija de puta te voy a sacar la casa te voy a matar no servis para nada
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      ROOT
# la          DET       det
# casa        NOUN      obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# no          ADV       advmod
# servis      VERB      advcl
# para        ADP       case
# nada        PRON      obl
#
# dame plata
# dame        PROPN     ROOT
# plata       NOUN      flat
#
# nunca me vas a olvidar si estas con alguien lo voy a hacer pelota
# nunca       ADV       advmod
# me          PRON      iobj
# vas         VERB      ROOT
# a           ADP       mark
# olvidar     VERB      xcomp
# si          SCONJ     mark
# estas       PRON      nsubj
# con         ADP       case
# alguien     PRON      nmod
# lo          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      xcomp
# pelota      NOUN      obj
#
# hija de puta puta de mierda te voy a sacar a los hijos te voy a matar sino me das a mis hijos te voy a matar me las voy a cobrar todas las que me hiciste yo sin mis hijos no me voy a ir de esta casa antes de irme te mato segui haciendo denuncias que asi te va a ir
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# puta        ADJ       amod
# de          ADP       case
# mierda      NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      ROOT
# a           ADP       case
# los         DET       det
# hijos       NOUN      obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# sino        CCONJ     cc
# me          PRON      obj
# das         VERB      conj
# a           ADP       case
# mis         DET       det
# hijos       NOUN      obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# me          PRON      obj
# las         PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cobrar      VERB      xcomp
# todas       DET       det
# las         DET       det
# que         SCONJ     obj
# me          PRON      obj
# hiciste     VERB      ccomp
# yo          PRON      nsubj
# sin         ADP       case
# mis         DET       det
# hijos       NOUN      obl
# no          ADV       advmod
# me          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# ir          VERB      conj
# de          ADP       case
# esta        DET       det
# casa        NOUN      obl
# antes       ADV       advmod
# de          ADP       mark
# irme        VERB      advcl
# te          PRON      obj
# mato        VERB      flat
# segui       VERB      advcl
# haciendo    VERB      xcomp
# denuncias   NOUN      obj
# que         SCONJ     mark
# asi         ADV       advmod
# te          PRON      obj
# va          AUX       aux
# a           ADP       mark
# ir          VERB      acl
#
# a vos mierda te voy a matar
# a           ADP       case
# vos         PROPN     obj
# mierda      ADJ       amod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
#
# zorra   te voy a garcar para mandar a alguien que te mate   puta   te voy a mandar a matar
# zorra       VERB      nsubj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# garcar      VERB      ROOT
# para        ADP       mark
# mandar      VERB      advcl
# a           ADP       case
# alguien     PRON      obj
# que         SCONJ     nsubj
# te          PRON      obj
# mate        VERB      acl
#             SPACE
# puta        NOUN      obj
#             SPACE
# te          PRON      iobj
# voy         AUX       aux
# a           ADP       mark
# mandar      VERB      advcl
# a           ADP       mark
# matar       VERB      xcomp
#
# no te rompo la cara porque estan los nenes
# no          ADV       advmod
# te          PRON      obj
# rompo       VERB      ROOT
# la          DET       det
# cara        NOUN      nsubj
# porque      SCONJ     mark
# estan       AUX       advcl
# los         DET       det
# nenes       NOUN      nsubj
#
# me estas provocando   queres que te cague a trompadas   vos buscas que yo te cague a piñas
# me          PRON      obj
# estas       PRON      aux
# provocando  VERB      ROOT
#             SPACE
# queres      NOUN      obj
# que         SCONJ     nsubj
# te          PRON      obj
# cague       VERB      ccomp
# a           ADP       case
# trompadas   NOUN      obj
#             SPACE
# vos         ADJ       amod
# buscas      ADJ       amod
# que         SCONJ     obj
# yo          PRON      nsubj
# te          PRON      obj
# cague       VERB      acl
# a           ADP       case
# piñas       NOUN      obj
#
# voy a matar a tu novio   tenes que hacer lo que yo te digo porque soy tu padre
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# a           ADP       case
# tu          DET       det
# novio       NOUN      obj
#             SPACE
# tenes       NOUN      amod
# que         SCONJ     cc
# hacer       VERB      acl
# lo          PRON      det
# que         SCONJ     obj
# yo          PRON      nsubj
# te          PRON      obj
# digo        VERB      ccomp
# porque      SCONJ     mark
# soy         AUX       cop
# tu          DET       det
# padre       NOUN      advcl
#
# te voy a romper la cabeza   tenes que irte de esta casa   te voy a matar
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# romper      VERB      advcl
# la          DET       det
# cabeza      NOUN      obj
#             SPACE
# tenes       NOUN      amod
# que         SCONJ     nsubj
# irte        VERB      acl
# de          ADP       case
# esta        DET       det
# casa        NOUN      obl
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
#
# sos una enferma de mierda hija de puta
# sos         VERB      ROOT
# una         DET       det
# enferma     NOUN      nsubj
# de          ADP       case
# mierda      ADJ       nmod
# hija        NOUN      amod
# de          ADP       case
# puta        NOUN      nmod
#
# puta sucia
# puta        NOUN      ROOT
# sucia       ADJ       amod
#
# queres quedarte con negros
# queres      PROPN     nsubj
# quedarte    VERB      ROOT
# con         ADP       case
# negros      NOUN      obj
#
# te fuiste con tus machos eres una puta  ahora vas a ver te voy a matar
# te          PRON      obj
# fuiste      VERB      ROOT
# con         ADP       case
# tus         DET       det
# machos      NOUN      obl
# eres        AUX       cop
# una         DET       det
# puta        NOUN      ccomp
#             SPACE
# ahora       ADV       advmod
# vas         ADJ       advcl
# a           ADP       mark
# ver         VERB      xcomp
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
#
# te voy a prender fuego la casa con vos adentro
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# prender     VERB      ROOT
# fuego       NOUN      obj
# la          DET       det
# casa        NOUN      obj
# con         ADP       case
# vos         ADJ       amod
# adentro     ADV       obl
#
# andate a dormir te voy a matar te voy a cagar a palos
# andate      PROPN     ROOT
# a           ADP       mark
# dormir      VERB      xcomp
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cagar       VERB      xcomp
# a           ADP       case
# palos       NOUN      obj
#
# te voy a sacar la nena
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      ROOT
# la          DET       det
# nena        NOUN      obj
#
# sos una hija de puta, te voy a matar
# sos         VERB      dep
# una         DET       det
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# ,           PUNCT     punct
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
#
# voy a pagar para que te maten
# voy         AUX       aux
# a           ADP       mark
# pagar       VERB      ROOT
# para        ADP       mark
# que         SCONJ     mark
# te          PRON      obj
# maten       AUX       advcl

# %% [markdown]
# spacy tambien permite buscar las entidades presentes en el texto
#    - En este caso observamos que en su mayoria no se logran identificar de forma satisfactoria entidades presentes. De todas formas no hay muchas entidades en las frases del dataset, ya que las frases consisten en su mayoria en insultos o amenazas que una persona le hace a otra, adicionalmente las frases del dataset se encuentran en su mayoria en minuscula lo que hace que al modelo se le dificulte identificar entidades como tal.

# %%
print("entidades identificadas :\n")
for doc in docs:
    for ent in doc.ents:
        print(f'{ent.text} : {ent.label_}')
# Out:
# entidades identificadas :
#
# aca : LOC
# palos qué lloras : LOC
# prender : PER
# venis : PER
# asi : ORG
# servis : LOC
# aca : LOC
# No te hagas : MISC
# Yo se donde vivís : MISC
# trola    : MISC
# gorda lechona : PER
# mi palabra : MISC
# la ley : LOC
# mi casa yo hago : MISC
# prender : PER
# trola : MISC
# aca : ORG
# servis : LOC
# mentirosa    : PER
# zorra    : MISC
# servis : LOC
# ocurra : LOC
# tenes : PER
# servis : LOC
# necesito : PER
# meter : LOC
# puta lesbiana : MISC
# soy : ORG
# puta lesbiana : MISC
# palos : LOC
# eh : ORG
# palos : LOC
# aca : LOC
# boca : ORG
# “Hola : PER
# ¿Querés : PER
# “Este viejo pajero te : MISC
# No camines sola : MISC
# Dale : ORG
# prender : PER
# prender : PER
# prender : PER
# zorra    : MISC
# meter : LOC
# vivis aca : PER
# zorra : MISC
# TE AMO CACHIRULA : MISC
# Este episodio : MISC
# “ : MISC
# Es menester hacer mención : MISC
# “Facebook : MISC
# puta sucia : ORG
# bajate : LOC
# qué me dejo : PER
# está : PER
# necesito : PER
# soy : MISC
# prender : PER
# servis : LOC
# soy : MISC
# puta zorra : MISC
# puta de mierda : MISC
# vieja : LOC
# andate : PER
# palos : LOC
# meter : LOC
# asi : ORG
# asi : ORG

# %% [markdown]
# Usando el PhraseMatcher de spacy podemos buscar instancias de palabras que pueden indicar amenazas o una frase amenazante.
# Con este podemos observar que las palabras "matar", "prender fuego" o "incendiar" aparecen 143 veces en las 337 frases del dataset.
# En este caso se busco en todas las frases como un texto entero, pero se puede aplicar de la misma forma a cada frase por separado .

# %%
from spacy.matcher import PhraseMatcher
from xl_text import excel_to_text

text = excel_to_text('set_de_datos_con_perspectiva_de_genero.xlsx', first_cell='S2', last_cell='S3827')
doc = nlp(text)
matcher = PhraseMatcher(nlp.vocab)
WORDS = ["matar", "prender fuego", "incendiar"]
patterns = [nlp(word) for word in WORDS]
matcher.add("AMENAZA_PATTERN", None, *patterns)
matches = matcher(doc)
threats = len(matches)
# matches contiene: match_id, start, end. Con eso puedo acceder al span que tiene el match. 
print(f'numero de apariciones de la palabra matar o similares: {threats}')
# Out:
# numero de apariciones de la palabra matar o similares: 143

# %% [markdown]
# Tambien se puede entrenar a un modelo de spacy para identificar esas palabras particulares como un nuevo tipo de entidad de texto que llamariamos 'amenaza'. Para esto creamos dos funciones get_training_data() y get_testing_data() que separan el dataset en datos de entrenamiento y de testeo. La data de entrenamiento es pasada a un conjunto de docs con las entidades 'amenaza' ya identificadas.
#  - con estos datos entrenamos al modelo y observamos que identifica 113 entidades 'amenaza' en 186 frases.
#  - si busco identificar si una frase es o no amenazante puedo suponer que si la frase tiene entidades amenazantes entonces lo es, en ese caso habria identificado 81 frases como amenazantes de las 186 analizadas.

# %%
import warnings
import random
from spacy.matcher import Matcher
from xl_text import excel_to_set

def get_training_data():
    """ Esta funcion devuelve una lista de la forma [(frase ,{"entities": entities})...] 
        donde se encuentran 150 de las frases del dataset, y las entidades 'amenazas' presentes en ellas
    """
    nlp1 = spacy.load("es_core_news_sm")
    matcher = Matcher(nlp1.vocab)
    pattern_1 = [{"LEMMA": "matar"}]
    pattern_2 = [{"LEMMA": "incendiar"}]
    pattern_3 = [{"LEMMA": "pagar"}]
    pattern_4 = [{"LOWER": "fuego"}]
    matcher.add("AMENAZA", None, pattern_1, pattern_2, pattern_3, pattern_4)
    training_data = []
    txts = list(excel_to_set('set_de_datos_con_perspectiva_de_genero.xlsx', first_cell='S2', last_cell='S3827'))
    docs = [nlp1(text) for text in txts[:150]]
    for doc in docs:
        matches = matcher(doc)
        spans = [doc[start:end] for match_id, start, end in matches]
        entities = [(span.start_char, span.end_char, "AMENAZA") for span in spans]
        training_example = (doc.text, {"entities": entities})
        training_data.append(training_example)
    return training_data


def get_testing_data():
    """ Esta funcion devuelve una lista de frases del dataset desde la frase 150 en adelante """
    txts = list(excel_to_set('set_de_datos_con_perspectiva_de_genero.xlsx', first_cell='S2', last_cell='S3827'))
    return txts[150:]

nlp = spacy.load("es_core_news_sm")
ner = nlp.get_pipe("ner")
ner.add_label("AMENAZA")
TRAINING_DATA = get_training_data()
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]  
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]  
with nlp.disable_pipes(*other_pipes), warnings.catch_warnings():  
    warnings.filterwarnings("once", category=UserWarning, module='spacy') 
    for itn in range(10):
        random.shuffle(TRAINING_DATA)
        losses = {}
        # Crea lotes con los ejemplos e itera sobre ellos
        for batch in spacy.util.minibatch(TRAINING_DATA, size=2):
            texts = [text for text, entities in batch]
            annotations = [entities for text, entities in batch]
            nlp.update(texts, annotations, losses=losses)
# path = Path('C:\Users\Usuario\Desktop\Practicas Profesionales\violencia de género\EDA\EDA_violencia_de_genero\projecto_eda')
# nlp.to_disk(path)

TESTING_DATA = get_testing_data()
docs = [nlp(text) for text in TESTING_DATA]
num_ent = 0
num_thr = 0
for doc in docs:
    print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
    num_ent += len(doc.ents) 
    if  len(doc.ents) > 0 :
        num_thr += 1
    for token in doc:
        token_text = token.text
        token_pos = token.pos_
        token_dep = token.dep_
        print("{:<12}{:<10}{:<10}".format(token_text, token_pos, token_dep))
        
print(f"el numero de entidades encontradas en {len(TESTING_DATA)} frases fue: {num_ent} entidades")
print(f' numero de frases con entidades: {num_thr}')
# Out:
# Entities [('matar', 'AMENAZA'), ('matar', 'AMENAZA')]
# soy         AUX       cop
# un          DET       det
# loco        NOUN      ROOT
# de          ADP       case
# mierda      NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      csubj
# voy         AUX       aux
# a           ADP       mark
# pasar       VERB      xcomp
# en          ADP       case
# cana        NOUN      obl
# toda        DET       det
# mi          DET       det
# vida        NOUN      obj
# pero        CCONJ     cc
# a           ADP       case
# ese         DET       det
# hijo        NOUN      obj
# de          ADP       case
# puta        NOUN      nmod
# lo          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      conj
# hija        NOUN      obj
# de          ADP       case
# re          PROPN     nmod
# mil         NUM       nummod
# puta        NOUN      flat
# Entities []
# no          ADV       advmod
# vas         VERB      ROOT
# a           ADP       mark
# poder       VERB      aux
# caminar     VERB      xcomp
# tranquila   NOUN      obj
# Entities [('matar', 'AMENAZA')]
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      ROOT
# la          DET       det
# casa        NOUN      obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# no          ADV       advmod
# servis      VERB      advcl
# para        ADP       case
# nada        PRON      obl
# Entities [('matar', 'AMENAZA')]
# necesito    VERB      csubj
# hablar      VERB      xcomp
# con         ADP       case
# vos         PROPN     obl
# no          ADV       advmod
# quiero      VERB      ROOT
# pelear      VERB      xcomp
# mas         PROPN     advmod
# puta        NOUN      obj
# de          ADP       case
# mierda      NOUN      nmod
# seguro      ADJ       amod
# tenes       NOUN      obj
# otro        DET       det
# macho       NOUN      nsubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# a           ADP       case
# vos         PROPN     obj
# y           CCONJ     cc
# al          ADP       case
# macho       INTJ      conj
# que         SCONJ     obj
# tengas      VERB      acl
# en          ADP       advmod
# serio       ADJ       fixed
# llamaste    INTJ      obj
# a           ADP       case
# la          DET       det
# policia     NOUN      obj
# si          SCONJ     mark
# no          ADV       advmod
# te          PRON      obj
# hice        VERB      advcl
# nada        PRON      obj
# Entities []
# que         SCONJ     mark
#             SPACE
# se          PRON      obj
# consiga     VERB      ROOT
# un          DET       det
# buen        ADJ       amod
# abogado     NOUN      nsubj
# porque      SCONJ     mark
# se          PRON      expl:pass
# esta        DET       obj
# equivocando VERB      advcl
# y           CCONJ     cc
# pronto      ADV       advmod
# voy         AUX       aux
# a           ADP       mark
# salir       VERB      conj
# Entities [('matar', 'AMENAZA'), ('matar', 'AMENAZA'), ('mato', 'AMENAZA')]
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# puta        ADJ       amod
# de          ADP       case
# mierda      NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      ROOT
# a           ADP       case
# los         DET       det
# hijos       NOUN      obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# sino        CCONJ     cc
# me          PRON      obj
# das         VERB      conj
# a           ADP       case
# mis         DET       det
# hijos       NOUN      obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# me          PRON      obj
# las         PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cobrar      VERB      xcomp
# todas       DET       det
# las         DET       det
# que         SCONJ     obj
# me          PRON      obj
# hiciste     VERB      ccomp
# yo          PRON      nsubj
# sin         ADP       case
# mis         DET       det
# hijos       NOUN      obl
# no          ADV       advmod
# me          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# ir          VERB      conj
# de          ADP       case
# esta        DET       det
# casa        NOUN      obl
#             SPACE
# antes       ADV       advmod
# de          ADP       mark
# irme        VERB      advcl
# te          PRON      obj
# mato        VERB      ccomp
# segui       VERB      advcl
# haciendo    VERB      xcomp
# denuncias   NOUN      obj
# que         SCONJ     mark
# asi         ADV       advmod
# te          PRON      obj
# va          AUX       aux
# a           ADP       mark
# ir          VERB      acl
# Entities []
# mi          DET       det
# palabra     NOUN      nsubj
# es          AUX       cop
# la          DET       det
# ley         NOUN      ROOT
# sos         VERB      amod
# una         DET       det
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# reventar    VERB      advcl
# la          DET       det
# cabeza      NOUN      obj
# te          PRON      obj
# veo         VERB      advcl
# afuera      VERB      obj
# y           CCONJ     cc
# te          PRON      obj
# reviento    VERB      conj
# toda        DET       obj
# Entities []
# sos         VERB      obj
# una         DET       det
# mierda      NOUN      nsubj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      csubj
# mierda      ADJ       obj
#             SPACE
# vos         ADJ       amod
# no          ADV       advmod
# tenes       NOUN      ROOT
# a           ADP       case
# nadie       PRON      obj
# Entities [('matar', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# desfigurar  VERB      xcomp
# toda        DET       det
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# abrir       VERB      xcomp
# la          DET       det
# panza       NOUN      obj
# me          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# llevar      VERB      advcl
# a           ADP       case
# la          DET       det
# nena        NOUN      obj
# Entities [('matar', 'AMENAZA')]
# los         DET       obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# a           ADP       case
# todos       PRON      obj
# Entities [('matar', 'AMENAZA')]
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# voy         AUX       aux
# a           ADP       mark
# volver      VERB      xcomp
# y           CCONJ     cc
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cortar      VERB      conj
# en          ADP       case
# pedacitos   NOUN      obl
# Entities []
# con         ADP       case
# quien       PRON      obl
# estas       DET       det
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# meter       VERB      ROOT
# un          DET       det
# tiro        NOUN      obj
# Entities []
# sos         VERB      det
# una         DET       det
# mala        ADJ       amod
# madre       NOUN      nsubj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      ROOT
# a           ADP       case
# tus         DET       det
# hijos       NOUN      obj
# Entities []
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# vos         ADJ       amod
# te          PRON      obj
# mereces     VERB      ROOT
# que         SCONJ     nsubj
# te          PRON      obj
# pegue       VERB      acl
# Entities [('matar', 'AMENAZA')]
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cortar      VERB      xcomp
# en          ADP       case
# pedacitos   NOUN      obl
# Entities []
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# puta        NOUN      amod
# de          ADP       case
# mierda      NOUN      nmod
#             SPACE
# no          ADV       advmod
# te          PRON      obj
# salva       VERB      ROOT
# ni          CCONJ     cc
# tu          DET       det
# mama        NOUN      obj
# Entities []
# les         PRON      obj
# voy         AUX       aux
# a           ADP       mark
# pegar       VERB      ROOT
# un          DET       det
# tiro        NOUN      obj
# Entities []
# dame        VERB      csubj
# el          DET       det
# celular     ADJ       nsubj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# romper      VERB      xcomp
# toda        DET       obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# romper      VERB      xcomp
# la          DET       det
# cabeza      NOUN      obj
# me          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# ir          VERB      ROOT
# pero        CCONJ     cc
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# romper      VERB      conj
# toda        DET       obj
# Entities []
# despues     NOUN      nsubj
# no          ADV       advmod
# queres      VERB      nsubj
# que         SCONJ     mark
# te          PRON      obj
# golpee      VERB      ccomp
#             SPACE
# te          PRON      obj
# vas         VERB      ROOT
# de          ADP       case
# aca         NOUN      obj
# pero        CCONJ     cc
# los         DET       det
# chicos      NOUN      nsubj
# se          PRON      obj
# quedan      AUX       conj
# Entities []
# vas         NOUN      ROOT
# a           ADP       mark
# ver         VERB      xcomp
# lo          PRON      det
# que         SCONJ     obj
# te          PRON      obj
# va          AUX       aux
# a           ADP       mark
# pasar       VERB      csubj
# Entities [('pagar', 'AMENAZA')]
# anda        VERB      ROOT
# a           ADP       mark
# saber       VERB      xcomp
# de          ADP       mark
# quien       PRON      mark
# estas       DET       det
# embarazada  ADJ       nsubj
#             SPACE
# no          ADV       advmod
# quiero      VERB      ccomp
# estar       VERB      cop
# con         ADP       case
# vos         PROPN     amod
# putita      NOUN      amod
# barata      ADJ       ccomp
#             SPACE
# me          PRON      iobj
# la          PRON      obj
# vas         NOUN      ccomp
# a           ADP       mark
# pagar       VERB      xcomp
#             SPACE
# puta        NOUN      obj
# de          ADP       case
# mierda      NOUN      nmod
#             SPACE
# anda        VERB      ccomp
# a           ADP       mark
# buscar      VERB      xcomp
# machos      NOUN      obj
# como        SCONJ     mark
# te          PRON      obj
# gusta       VERB      advcl
# hacer       VERB      csubj
# Entities [('matar', 'AMENAZA')]
# por         ADP       case
# que         SCONJ     obl
# me          PRON      obj
# sacaste     VERB      ccomp
# a           ADP       case
# mis         DET       det
# hijas       NOUN      obj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      csubj
# a           ADP       case
# mi          DET       obj
# no          ADV       advmod
# me          PRON      obj
# importa     VERB      ROOT
# ningun      NOUN      nsubj
# juez        NOUN      amod
# Entities [('matar', 'AMENAZA')]
# si          SCONJ     mark
# te          PRON      obj
# veo         VERB      advcl
# con         ADP       case
# otra        DET       det
# persona     NOUN      obl
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# Entities []
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# partir      VERB      ROOT
# la          DET       det
# cabeza      NOUN      obj
# en          ADP       case
# cuatro      NUM       obl
# Entities []
# sos         VERB      ROOT
# una         DET       det
# puta        NOUN      nsubj
# estabas     VERB      amod
# con         ADP       case
# tus         DET       det
# machos      NOUN      nmod
# donde       PRON      obl
# fuiste      VERB      acl
# por         ADP       mark
# que         SCONJ     mark
# no          ADV       advmod
# llegaste    VERB      ccomp
# a           ADP       case
# casa        NOUN      obl
# Entities [('matar', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
#             SPACE
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      nmod
# Entities []
# no          ADV       advmod
# te          PRON      obj
# metas       VERB      ROOT
# mas         CCONJ     advmod
# conmigo     PRON      nsubj
#             SPACE
# no          ADV       advmod
# vas         VERB      conj
# a           ADP       mark
# ver         VERB      xcomp
# mas         ADV       obj
# a           ADP       case
# las         DET       det
# nenas       NOUN      obj
#             SPACE
# ya          ADV       advmod
# se          PRON      obj
# donde       PRON      obl
# te          PRON      obj
# mudaste     VERB      advcl
# Entities []
# soy         AUX       cop
# tu          DET       det
# marido      NOUN      ROOT
# y           CCONJ     cc
# te          PRON      obj
# toco        VERB      conj
# todo        DET       det
# lo          PRON      det
# que         SCONJ     obj
# quiero      VERB      ccomp
# Entities []
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# me          PRON      iobj
# estas       DET       aux
# cagando     VERB      csubj
#             SPACE
# vas         VERB      aux
# a           ADP       mark
# ver         VERB      xcomp
# lo          PRON      det
# que         SCONJ     obj
# te          PRON      obj
# va          AUX       aux
# a           ADP       mark
# pasar       VERB      ccomp
#             SPACE
# no          ADV       advmod
# tengo       VERB      ROOT
# nada        PRON      obj
# que         SCONJ     obj
# perder      VERB      acl
#             SPACE
# nadie       PRON      nsubj
# te          PRON      obj
# va          AUX       aux
# a           ADP       mark
# poder       VERB      aux
# salvar      VERB      conj
# Entities []
# puta        NOUN      nsubj
# ahi         PROPN     flat
# estan       AUX       ROOT
# tus         SCONJ     det
# macho       VERB      obj
# Entities []
# queres      PROPN     nsubj
# quedarte    PROPN     nsubj
# con         ADP       case
# negros      NOUN      obj
#             SPACE
# no          ADV       advmod
# sabes       VERB      ROOT
# quien       PRON      mark
# soy         AUX       ccomp
# yo          PRON      nsubj
# Entities [('matar', 'AMENAZA')]
# puta        NOUN      dep
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# chupame     ADV       obj
# la          DET       det
# pija        NOUN      obj
# Entities [('matar', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# cuando      SCONJ     mark
# te          PRON      obj
# vea         VERB      advcl
# con         ADP       case
# otro        PRON      obl
# Entities []
# despues     NOUN      nsubj
# se          PRON      obj
# llenan      AUX       ROOT
# la          DET       det
# boca        NOUN      nsubj
# hablando    VERB      advcl
# de          ADP       case
# ni          ADV       advmod
# una         DET       det
# menos       ADV       obj
# Entities []
# hija        NOUN      ROOT
# de          ADP       case
# puta        NOUN      nmod
# inutil      ADJ       amod
# Entities [('meter', 'AMENAZA')]
# no          ADV       advmod
# vas         VERB      advcl
# a           ADP       mark
# subir       VERB      xcomp
# mas         ADV       obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# meter       VERB      ROOT
# presa       ADJ       obj
# hacete      PROPN     nsubj
# coger       VERB      advcl
# para        ADP       mark
# que         SCONJ     mark
# te          PRON      obj
# paguen      VERB      advcl
# cinco       NUM       nummod
# mil         NUM       obj
# para        ADP       case
# las         DET       det
# zapatillas  NOUN      obl
# de          ADP       case
# tu          DET       nmod
# nene        VERB      advcl
# Entities []
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# apuñalar    VERB      ROOT
# Entities []
# tenes       NOUN      nsubj
# novio       NOUN      flat
#             SPACE
# me          PRON      obj
# das         VERB      ROOT
# tu          DET       det
# numero      NOUN      obj
# de          ADP       case
# telefono    NOUN      nmod
# Entities []
# pelotudo    PROPN     nsubj
# inutil      ADJ       obj
# de          ADP       case
# mierda      PROPN     nmod
# no          ADV       advmod
# servis      VERB      ROOT
# para        ADP       case
# nada        PRON      obl
# Entities [('matar', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# voy         AUX       aux
# a           ADP       mark
# romper      VERB      xcomp
# la          DET       det
# casa        NOUN      obj
# Entities []
# si          SCONJ     mark
# no          ADV       advmod
# me          PRON      obj
# dejas       VERB      advcl
# entrar      VERB      xcomp
# por         ADP       case
# las         DET       det
# buenas      ADJ       obl
# voy         AUX       aux
# a           ADP       mark
# entrar      VERB      ROOT
# por         ADP       case
# las         DET       det
# malas       NOUN      obl
# Entities []
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# mañana      ADV       advmod
# no          ADV       advmod
# vas         VERB      ROOT
# a           ADP       case
# estar       VERB      cop
# viva        ADJ       xcomp
# Entities []
# vistes      PROPN     nsubj
# que         SCONJ     nsubj
# tenias      NOUN      acl
# otro        DET       det
# macho       INTJ      amod
# vas         INTJ      ROOT
# a           ADP       mark
# agachar     VERB      xcomp
# la          DET       det
# cabeza      NOUN      obj
# cuando      SCONJ     mark
# mires       NOUN      advcl
# a           ADP       case
# la          DET       det
# cara        NOUN      nmod
# puta        ADJ       amod
# pedazo      NOUN      amod
# de          ADP       case
# atorranta   ADJ       nmod
# Entities []
# te          PRON      obj
# gusta       VERB      ROOT
# mi          DET       det
# pija        NOUN      nsubj
# amor        NOUN      appos
# Entities [('mato', 'AMENAZA'), ('matar', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# quemar      VERB      ROOT
# la          DET       det
# casa        NOUN      obj
#             SPACE
# si          SCONJ     mark
# haces       VERB      advcl
# la          DET       det
# denuncia    NOUN      obj
# te          PRON      obj
# mato        VERB      advcl
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# a           ADP       case
# vos         PROPN     obj
# y           CCONJ     cc
# a           ADP       case
# tus         DET       det
# hijos       NOUN      conj
# Entities []
# no          ADV       advmod
# vas         VERB      ROOT
# a           ADP       mark
# estar       VERB      xcomp
# con         ADP       case
# nadie       PRON      obl
# no          ADV       advmod
# te          PRON      iobj
# voy         AUX       aux
# a           ADP       mark
# dejar       VERB      conj
# estar       VERB      xcomp
# con         ADP       case
# nadie       PRON      obl
# vos         ADJ       amod
# sos         VERB      det
# mia         NOUN      xcomp
# Entities []
# gorda       PROPN     nsubj
# lechona     PROPN     flat
# vas         ADJ       csubj
# a           ADP       mark
# vivir       VERB      xcomp
# toda        DET       det
# tu          DET       det
# vida        NOUN      obj
# asi         ADV       advmod
# te          PRON      obj
# falta       VERB      ROOT
# mucho       ADV       advmod
# para        ADP       mark
# bajar       VERB      advcl
# de          ADP       case
# peso        NOUN      obl
# Entities []
# trola       VERB      nsubj
# ya          ADV       advmod
# no          ADV       advmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# escribir    VERB      ROOT
# mas         PROPN     advmod
# andate      VERB      obj
# a           ADP       case
# la          DET       det
# concha      NOUN      obj
# de          ADP       case
# tu          DET       det
# madre       NOUN      nmod
# Entities []
# sos         VERB      ROOT
# una         DET       det
# enferma     NOUN      nsubj
# de          ADP       case
# mierda      ADJ       nmod
# hija        NOUN      amod
# de          ADP       case
# puta        NOUN      nmod
# Entities []
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      ROOT
# algo        PRON      obj
# que         SCONJ     mark
# te          PRON      obj
# va          AUX       aux
# a           ADP       case
# doler       VERB      acl
# Entities []
# puta        NOUN      nsubj
# zorra       PROPN     flat
# quedate     VERB      ROOT
# en          ADP       case
# el          DET       det
# molde       NOUN      obl
# sino        CCONJ     cc
# te          PRON      obj
# pego        VERB      conj
# cuatro      NUM       nummod
# tiros       NOUN      nsubj
# yo          PRON      appos
# con         ADP       case
# vos         ADJ       obl
# hago        VERB      advcl
# lo          PRON      det
# que         SCONJ     obj
# quiero      VERB      ccomp
# Entities [('matar', 'AMENAZA')]
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# no          ADV       advmod
# servis      VERB      csubj
# para        ADP       case
# nada        INTJ      obl
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# encontrar   VERB      xcomp
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# te          PRON      obj
# vas         VERB      ROOT
# a           ADP       mark
# morir       VERB      xcomp
# de          ADP       case
# hambre      NOUN      obl
# Entities [('matar', 'AMENAZA')]
# yo          PRON      nsubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# reventar    VERB      ROOT
# la          DET       det
# cabeza      NOUN      obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# reventar    VERB      xcomp
# sos         ADV       obj
# una         DET       det
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      nmod
# Entities []
# zorra       VERB      nsubj
#             SPACE
# mira        VERB      ROOT
# lo          PRON      det
# que         SCONJ     obj
# tengo       VERB      ccomp
# y           CCONJ     cc
# lo          PRON      obj
# puedo       AUX       aux
# usar        VERB      conj
# en          ADP       case
# tu          DET       obl
# contra      ADP       flat
# Entities [('pago', 'AMENAZA')]
# concha      NOUN      nsubj
# de          ADP       case
# tu          DET       det
# madre       NOUN      nmod
#             SPACE
# yo          PRON      appos
# pago        VERB      flat
# aca         VERB      appos
# vos         ADJ       flat
# te          PRON      iobj
# vas         VERB      ROOT
# a           ADP       mark
# ir          VERB      xcomp
# Entities [('matar', 'AMENAZA')]
# vecino      NOUN      nsubj
# de          ADP       case
# mierda      NOUN      nmod
# los         DET       obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# Entities [('matar', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# desaparecer VERB      xcomp
# a           ADP       case
# tus         DET       det
# hijos       NOUN      obl
# los         PRON      obj
# voy         AUX       aux
# a           ADP       mark
# agarrar     VERB      xcomp
# tambien     NOUN      obj
# Entities []
# sos         VERB      obj
# una         DET       det
# trola       ADJ       nsubj
# puta        NOUN      amod
#             SPACE
# vos         ADJ       appos
# te          PRON      obj
# sacas       VERB      ROOT
# las         DET       det
# ganas       NOUN      nsubj
# con         ADP       case
# tus         DET       det
# compañeros  NOUN      obl
# del         ADP       case
# colegio     NOUN      nmod
#             SPACE
# por         ADP       case
# eso         PRON      obl
# no          ADV       advmod
# queres      VERB      advcl
# estar       VERB      cop
# conmigo     PRON      nsubj
# Entities []
# la          DET       det
# concha      NOUN      ROOT
# de          ADP       case
# tu          DET       det
# madre       NOUN      nmod
#             SPACE
# puta        NOUN      amod
#             SPACE
# andate      PROPN     flat
# de          ADP       case
# la          DET       det
# casa        NOUN      nmod
# Entities []
# este        DET       det
# celular     NOUN      nsubj
# se          PRON      obj
# rompe       VERB      ROOT
# aca         ADJ       obj
# Entities [('matar', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# pasar       VERB      advcl
# por         ADP       case
# encima      ADV       fixed
# con         ADP       case
# el          DET       det
# auto        NOUN      obl
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# Entities [('matar', 'AMENAZA')]
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# Entities [('pagar', 'AMENAZA')]
# voy         AUX       aux
# a           ADP       mark
# pagar       VERB      ROOT
# para        ADP       mark
# que         SCONJ     mark
# te          PRON      obj
# maten       AUX       advcl
# no          ADV       advmod
# me          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# ensuciar    VERB      csubj
# las         DET       det
# manos       NOUN      obj
# Entities []
# por         ADP       case
# tu          DET       det
# culpa       NOUN      obl
# estuve      VERB      aux
# detenido    ADJ       ROOT
# toda        DET       det
# la          DET       det
# noche       NOUN      obl
# Entities []
# nunca       ADV       advmod
# me          PRON      iobj
# vas         VERB      ROOT
# a           ADP       mark
# olvidar     VERB      xcomp
# si          SCONJ     mark
# estas       PRON      nsubj
# con         ADP       case
# alguien     PRON      nmod
# lo          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      xcomp
# pelota      NOUN      obj
# Entities [('pagar', 'AMENAZA'), ('matar', 'AMENAZA')]
# sos         VERB      iobj
# una         DET       det
# puta        NOUN      nsubj
# me          PRON      iobj
# la          DET       obj
# vas         NOUN      ROOT
# a           ADP       mark
# pagar       VERB      xcomp
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# estas       PRON      obj
# con         ADP       case
# otro        PRON      obl
# Entities []
# vieja       ADJ       nsubj
# de          ADP       case
# mierda      NOUN      nmod
# no          ADV       advmod
# rompa       VERB      ROOT
# las         DET       det
# pelotas     NOUN      obj
# porque      SCONJ     mark
# la          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cagar       VERB      advcl
# a           ADP       case
# trompadas   NOUN      obj
# Entities [('matando', 'AMENAZA'), ('matar', 'AMENAZA'), ('mato', 'AMENAZA')]
# puta        NOUN      nsubj
# de          ADP       case
# mierda      PROPN     nmod
# traes       AUX       advcl
# a           ADP       case
# tus         DET       det
# machos      NOUN      obj
# aca         NOUN      appos
# te          PRON      obj
# los         PRON      obj
# voy         AUX       aux
# a           ADP       mark
# terminar    VERB      xcomp
# matando     VERB      obj
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      conj
# y           CCONJ     cc
# despues     NOUN      conj
# me          PRON      obj
# mato        VERB      ROOT
# yo          PRON      nsubj
# con         ADP       case
# quien       PRON      obl
# estabas     VERB      acl
#             SPACE
# callate     NOUN      nsubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# romper      VERB      advcl
# la          DET       det
# boca        NOUN      obj
# Entities []
# si          SCONJ     mark
# no          ADV       advmod
# venis       VERB      advcl
# conmigo     PRON      obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# romper      VERB      ROOT
# toda        DET       obj
# Entities []
# te          PRON      obj
# va          AUX       aux
# a           ADP       mark
# pasar       VERB      ROOT
# lo          PRON      det
# mismo       PRON      obj
# que         SCONJ     mark
# a           ADP       case
# tu          DET       det
# hermano     NOUN      nmod
# Entities [('matar', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# perra       INTJ      obj
#             SPACE
# puta        ADJ       obj
# de          ADP       case
# esta        PRON      nmod
# no          ADV       advmod
# te          PRON      obj
# salvas      VERB      conj
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      advcl
# el          DET       det
# bebe        NOUN      obj
# Entities []
# que         SCONJ     mark
# no          ADV       advmod
# se          PRON      obj
# note        VERB      ROOT
# que         SCONJ     mark
# sos         DET       det
# facil       ADV       csubj
# Entities []
# vos         ADJ       ROOT
# sos         PROPN     flat
# mia         NOUN      compound
# Entities []
# perra       PROPN     nsubj
#             SPACE
# puta        NOUN      amod
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# quitar      VERB      ROOT
# a           ADP       case
# mi          DET       det
# hija        NOUN      obj
# Entities []
# sos         VERB      ROOT
# una         DET       det
# putita      NOUN      amod
# sos         NOUN      nsubj
# rapida      ADJ       amod
# Entities [('matar', 'AMENAZA'), ('matar', 'AMENAZA')]
# puta        NOUN      nsubj
#             SPACE
# si          SCONJ     mark
# te          PRON      obj
# encuentro   VERB      advcl
# con         ADP       case
# otro        PRON      obl
# no          ADV       advmod
# lo          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# a           ADP       case
# el          DET       det
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# a           ADP       case
# vos         PROPN     obj
#             SPACE
# no          ADV       advmod
# servis      VERB      advcl
# para        ADP       case
# nada        PRON      obl
# Entities [('matar', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      csubj
# conchuda    NOUN      obj
# ya          ADV       advmod
# no          ADV       advmod
# te          PRON      obj
# aguanto     VERB      ROOT
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      nmod
# Entities [('matar', 'AMENAZA')]
# no          ADV       advmod
# me          PRON      obj
# importa     VERB      ROOT
# nada        PRON      nsubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      csubj
#             SPACE
# puta        NOUN      obj
# de          ADP       case
# mierda      NOUN      nmod
# trola       ADJ       flat
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# arruinar    VERB      csubj
# muerto      ADJ       obj
# o           CCONJ     cc
# preso       ADJ       conj
# no          ADV       advmod
# me          PRON      obj
# importa     VERB      advcl
# no          ADV       advmod
# te          PRON      obj
# mereces     VERB      csubj
# a           ADP       case
# mi          DET       det
# hijo        NOUN      obj
# Entities []
# puta        NOUN      nsubj
#             SPACE
# perra       PROPN     ROOT
#             SPACE
# mantenida   ADJ       obj
# Entities [('matar', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# Entities [('matar', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
#             SPACE
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cagar       VERB      xcomp
# a           ADP       advmod
# piñas       NOUN      fixed
# Entities []
# queres      PROPN     nsubj
# quedarte    VERB      ROOT
# con         ADP       case
# negros      NOUN      obj
# Entities []
# puta        NOUN      ROOT
# perra       ADJ       flat
# Entities [('matar', 'AMENAZA')]
# sos         VERB      dep
# una         DET       det
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# ,           PUNCT     punct
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# Entities [('matar', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# romper      VERB      advcl
# la          DET       det
# cabeza      NOUN      obj
#             SPACE
# tenes       NOUN      amod
# que         SCONJ     nsubj
# irte        VERB      acl
# de          ADP       case
# esta        DET       det
# casa        NOUN      obl
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# Entities [('matar', 'AMENAZA')]
# sucia       ADJ       nsubj
# de          ADP       case
# mierda      NOUN      nmod
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# Entities [('matar', 'AMENAZA')]
# sos         VERB      advcl
# una         DET       det
# negra       NOUN      nsubj
# de          ADP       case
# mierda      NOUN      nmod
# ,           PUNCT     punct
# no          ADV       advmod
# voy         VERB      ROOT
# a           ADP       mark
#
#            SPACE
# parar       VERB      xcomp
# de          ADP       case
# molestarte  NOUN      obj
# hasta       ADP       mark
# que         SCONJ     mark
# te          PRON      obj
# mudes       NOUN      advcl
# de          ADP       case
# aca         NOUN      nmod
# negra       ADJ       amod
# mierda      ADJ       nsubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      advcl
#
#            SPACE
# y           CCONJ     cc
# a           ADP       case
# vos         PROPN     amod
# pelado      INTJ      conj
# que         SCONJ     mark
# decis       VERB      acl
# que         SCONJ     mark
# me          PRON      iobj
# la          PRON      obj
# vas         NOUN      ccomp
# a           ADP       mark
# dar         VERB      xcomp
# anda        NOUN      amod
# cagala      NOUN      obj
# a           ADP       case
# palos       NOUN      obj
# qué         DET       det
# lloras      NOUN      nsubj
# le          PRON      obj
# tenes       NOUN      ccomp
# miedo       NOUN      obj
# a           ADP       case
# esa         DET       det
# negra       NOUN      nmod
# de          ADP       case
# mierda      NOUN      nmod
# Entities []
# no          ADV       advmod
# te          PRON      obj
# hagas       VERB      ROOT
# la          DET       det
# viva        NOUN      obj
# que         SCONJ     obj
# sabemos     VERB      acl
# tus         DET       det
# horarios    NOUN      obj
# y           CCONJ     cc
# que         SCONJ     mark
# vivis       PROPN     nsubj
# aca         VERB      flat
#             SPACE
# te          PRON      obj
# hago        VERB      conj
# un          DET       det
# monton      NOUN      obj
# de          ADP       case
# hijos       NOUN      nmod
#             SPACE
# te          PRON      obj
# parto       VERB      advcl
# en          ADP       case
# ocho        NUM       nummod
#             SPACE
# ya          ADV       advmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# agarrar     VERB      advcl
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      advcl
# mierda      NOUN      obj
# Entities [('pagar', 'AMENAZA'), ('pagar', 'AMENAZA'), ('matar', 'AMENAZA')]
# te          PRON      obj
# va          AUX       aux
# a           ADP       mark
# ir          VERB      ROOT
# muy         ADV       advmod
# mal         ADV       advmod
# todo        DET       det
# lo          PRON      det
# que         SCONJ     nsubj
# estas       PRON      nsubj
# haciendo    VERB      csubj
# lo          PRON      det
# vas         INTJ      conj
# a           ADP       mark
# pagar       VERB      xcomp
# tu          DET       det
# familia     NOUN      nsubj
# es          AUX       cop
# una         DET       det
# mierda      NOUN      advcl
# te          PRON      obj
# van         VERB      aux
# a           ADP       mark
# garchar     PROPN     advcl
# te          PRON      obj
# van         VERB      aux
# a           ADP       mark
# coger       VERB      advcl
# la          DET       det
# vas         NOUN      obj
# a           ADP       mark
# pagar       VERB      advcl
# muy         ADV       advmod
# caro        ADJ       amod
# odio        NOUN      obj
# a           ADP       case
# tu          DET       det
# familia     NOUN      obj
# toda        DET       det
# tu          DET       det
# familia     NOUN      obj
# intento     NOUN      amod
# separarnos  ADJ       flat
# tengo       VERB      advcl
# un          DET       det
# arma        NOUN      obj
# en          ADP       case
# la          DET       det
# casa        NOUN      obl
# de          ADP       case
# mi          DET       det
# mama        NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      advcl
# Entities []
# dame        VERB      csubj
# a           ADP       case
# mi          DET       det
# hija        NOUN      obj
# te          PRON      obj
# tiro        VERB      ROOT
# la          DET       det
# puerta      NOUN      obj
# abajo       ADV       advmod
# Entities []
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# vos         ADJ       amod
# te          PRON      obj
# mereces     NOUN      ROOT
# que         SCONJ     nsubj
# te          PRON      obj
# ...
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      advcl
# algo        PRON      obj
# que         SCONJ     nsubj
# te          PRON      obj
# va          AUX       aux
# a           ADP       case
# doler       VERB      acl
# ,           PUNCT     punct
# porque      SCONJ     mark
# yo          PRON      nsubj
# a           ADP       case
# vos         PROPN     amod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      advcl
# y           CCONJ     cc
# a           ADP       case
# el          DET       det
# tambien     NOUN      obj
# yo          PRON      nsubj
# te          PRON      obj
# voy         VERB      conj
# a           ADP       mark
#
#            SPACE
# encontrar   VERB      advcl
# y           CCONJ     cc
# me          PRON      iobj
# las         DET       obj
# vas         NOUN      conj
# a           ADP       mark
# pagar       VERB      advcl
# yo          PRON      nsubj
# le          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# toda        DET       det
# su          DET       det
# familia     NOUN      obj
# ,           PUNCT     punct
# este        DET       appos
# con         ADP       case
#
#            SPACE
# vos         ADJ       amod
# o           CCONJ     cc
# no          ADV       advmod
# esté        VERB      cop
# con         ADP       case
# vos         PROPN     conj
# ,           PUNCT     punct
# mudate      NOUN      appos
# a           ADP       case
# donde       PRON      nmod
# sea         VERB      cop
# ,           PUNCT     punct
# yo          PRON      nsubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# encontrar   VERB      advcl
# puta        NOUN      obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# prender     VERB      advcl
# fuego       NOUN      compound
# a           ADP       case
# ella        PRON      obj
# ,           PUNCT     punct
# a           ADP       case
# su          DET       det
# familia     NOUN      obl
# ,           PUNCT     punct
# que         SCONJ     nsubj
# la          PRON      obj
# iba         VERB      aux
# a           ADP       mark
# matar       VERB      acl
# ,           PUNCT     punct
# y           CCONJ     cc
# que         SCONJ     mark
# no          ADV       advmod
# se          PRON      obj
# le          PRON      obj
# ocurriera   AUX       conj
# aparecer    VERB      csubj
# porque      SCONJ     mark
# no          ADV       advmod
# la          PRON      obj
# contaba     AUX       advcl
# traeme      VERB      xcomp
# al          ADP       case
# nene        NOUN      advcl
# ,           PUNCT     punct
# mas         PROPN     advmod
# vale        VERB      ROOT
# que         SCONJ     mark
# lo          PRON      obj
# traigas     VERB      ccomp
# ,           PUNCT     punct
# los         DET       obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# a           ADP       case
# todos       PRON      obj
# ,           PUNCT     punct
# no          ADV       advmod
# me          PRON      obj
# hagas       AUX       advcl
# poner       VERB      csubj
# loco        PROPN     obj
# ,           PUNCT     punct
# los         DET       obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      advcl
# a           ADP       case
# todos       PRON      obj
# Entities []
# puta        NOUN      ROOT
# de          ADP       case
# mierda      NOUN      nmod
# Entities []
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      ROOT
# quilombo    NOUN      obj
# en          ADP       case
# tu          DET       det
# casa        NOUN      obl
# y           CCONJ     cc
# en          ADP       case
# tu          DET       det
# trabajo     NOUN      obl
# vieja       ADJ       amod
# de          ADP       case
# mierda      NOUN      nmod
#             SPACE
# llama       VERB      advcl
# a           ADP       case
# la          DET       det
# policia     NOUN      obj
# aca         PROPN     flat
# espero      PROPN     advcl
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# hacer       VERB      advcl
# echar       VERB      xcomp
# del         ADP       case
# trabajo     NOUN      obl
# Entities []
# negra       ADJ       amod
# villera     AUX       ROOT
#             SPACE
# puta        ADJ       nsubj
# muerta      ADJ       amod
# de          ADP       case
# hambre      NOUN      nmod
# hoy         ADV       advmod
# voy         AUX       aux
# a           ADP       mark
# comer       VERB      xcomp
# y           CCONJ     cc
# vos         ADJ       conj
# no          ADV       advmod
# a           ADP       case
# mi          DET       det
# nadie       PRON      obj
# me          PRON      obj
# toca        VERB      advcl
#             SPACE
# ya          ADV       advmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# agarrar     VERB      advcl
# sola        ADJ       obj
# Entities [('matar', 'AMENAZA'), ('matar', 'AMENAZA')]
# porque      SCONJ     mark
# sos         DET       nsubj
# asi         ADV       advmod
# vos         ADJ       amod
# no          ADV       advmod
# eras        AUX       advcl
# asi         ADV       advmod
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      csubj
# a           ADP       case
# los         DET       det
# chicos      NOUN      obj
#             SPACE
# vos         ADJ       obj
# te          PRON      obj
# vas         VERB      ROOT
# con         ADP       mark
# el          DET       det
#             SPACE
# lo          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      advcl
# a           ADP       mark
# el          DET       det
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      xcomp
# Entities [('mato', 'AMENAZA')]
# la          DET       det
# concha      NOUN      ROOT
# de          ADP       case
# tu          DET       det
# madre       NOUN      nmod
# donde       PRON      obl
# estas       DET       det
# la          DET       det
# concha      NOUN      nsubj
# de          ADP       case
# tu          DET       nmod
# madre       NOUN      flat
# te          PRON      obj
# mato        VERB      acl
# perra       PROPN     obj
# Entities []
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# acuchillar  VERB      csubj
#             SPACE
# ni          CCONJ     cc
# tu          DET       det
# boton       NOUN      conj
# antipanico  ADJ       amod
# te          PRON      obj
# va          AUX       aux
# a           ADP       mark
# salvar      VERB      ROOT
# Entities []
# no          ADV       advmod
# me          PRON      obj
# rompas      VERB      ROOT
# las         DET       det
# pelotas     NOUN      nsubj
# porque      SCONJ     mark
# me          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# ir          VERB      advcl
# Entities [('mato', 'AMENAZA')]
# yo          PRON      nsubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# encontrar   VERB      ROOT
# y           CCONJ     cc
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# pegar       VERB      conj
# un          DET       det
# tiro        NOUN      obj
# nos         PRON      obj
# vemos       VERB      advcl
# o           CCONJ     cc
# te          PRON      obj
# busco       VERB      conj
# te          PRON      obj
# mato        VERB      conj
# y           CCONJ     cc
# listo       ADJ       conj
# Entities []
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# sacar       VERB      ROOT
# la          DET       det
# nena        NOUN      obj
# Entities [('matar', 'AMENAZA')]
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
#             SPACE
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ROOT
# voy         AUX       aux
# a           ADP       mark
# volver      VERB      xcomp
# y           CCONJ     cc
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# cortar      VERB      conj
# en          ADP       case
# pedacitos   NOUN      obl
# Entities []
# vos         ADJ       nsubj
# sos         PRON      ROOT
# la          DET       det
# segunda     ADJ       obj
# Entities []
# no          ADV       advmod
# te          PRON      obj
# rompo       VERB      ROOT
# la          DET       det
# cara        NOUN      nsubj
# porque      SCONJ     mark
# estan       AUX       advcl
# los         DET       det
# nenes       NOUN      nsubj
# Entities [('fuego', 'AMENAZA')]
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# prender     VERB      ROOT
# fuego       NOUN      obj
# Entities []
# sos         VERB      iobj
# una         DET       det
# desgraciada ADJ       amod
#             SPACE
# maldita     ADJ       amod
#             SPACE
# yo          PRON      nsubj
# te          PRON      iobj
# quiero      VERB      ROOT
# pero        CCONJ     cc
# a           ADP       case
# vos         PROPN     obj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# castigar    VERB      conj
# Entities []
# vos         ADJ       nsubj
# no          ADV       advmod
# sos         VERB      nmod
# nadie       PRON      ROOT
#             SPACE
# sos         VERB      appos
# una         DET       det
# simple      ADJ       amod
# empleada    NOUN      appos
# estas       DET       amod
# para        ADP       mark
# limpiar     VERB      acl
# aca         NOUN      obj
# Entities []
# si          SCONJ     mark
# a           ADP       case
# mi          DET       obj
# me          PRON      obj
# pasa        VERB      ROOT
# algo        PRON      nsubj
# donde       PRON      obl
# te          PRON      obj
# vea         VERB      acl
# te          PRON      obj
# puedo       AUX       aux
# hacer       VERB      xcomp
# algo        PRON      obj
# Entities []
# con         ADP       case
# mi          DET       det
# plata       NOUN      obl
# hago        VERB      ROOT
# lo          PRON      det
# que         SCONJ     obj
# quiero      VERB      ccomp
# Entities []
# si          SCONJ     mark
# no          ADV       advmod
# sos         VERB      nmod
# mia         NOUN      nsubj
# no          ADV       advmod
# sos         ADJ       ROOT
# de          ADP       case
# nadie       PRON      nmod
# Entities [('matar', 'AMENAZA'), ('matar', 'AMENAZA')]
# hija        NOUN      nsubj
# de          ADP       case
# puta        NOUN      nmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      csubj
# eso         PRON      obj
# es          AUX       ROOT
# lo          PRON      det
# que         SCONJ     obj
# vos         ADJ       amod
# queres      NOUN      nsubj
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# matar       VERB      ccomp
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      nmod
# Entities []
# boluda      ADJ       amod
# hija        NOUN      ROOT
# de          ADP       case
# puta        NOUN      nmod
# vos         ADJ       amod
# queres      NOUN      amod
# que         SCONJ     nsubj
# te          PRON      obj
# golpee      VERB      acl
# Entities []
# ahora       ADV       advmod
# te          PRON      obj
# voy         AUX       aux
# a           ADP       mark
# dejar       VERB      ROOT
# yo          PRON      nsubj
# marcas      NOUN      amod
# en          ADP       case
# la          DET       det
# boca        NOUN      obl
#             SPACE
# a           ADP       mark
# ver         VERB      xcomp
# hija        NOUN      obj
# de          ADP       case
# puta        NOUN      nmod
# estas       DET       det
# depilada    ADJ       appos
#             SPACE
# a           ADP       mark
# ver         VERB      xcomp
# si          SCONJ     mark
# estas       DET       det
# dilatada    ADJ       obj
# Entities []
# puta        NOUN      nsubj
# de          ADP       case
# mierda      NOUN      nmod
# ,           PUNCT     punct
# vos         ADJ       amod
# seguro      ADV       amod
# estas       DET       det
# con         ADP       case
# mi          DET       det
# sobrino     NOUN      nmod
#             SPACE
# vos         ADJ       appos
# le          PRON      obj
# abris       VERB      ROOT
# las         DET       det
# piernas     NOUN      obj
# a           ADP       case
# cualquiera  PRON      nmod
# Entities [('matar', 'AMENAZA')]
# a           ADP       case
# vos         PROPN     obl
# te          PRON      obj
# tengo       VERB      ROOT
# que         SCONJ     cc
# matar       VERB      conj
# Entities []
# estupida    ADJ       advcl
# tarada      ADJ       flat
# yo          PRON      nsubj
# te          PRON      iobj
# lo          PRON      obj
# prometo     VERB      ROOT
# que         SCONJ     mark
# te          PRON      obj
# hago        VERB      ccomp
# la          DET       det
# vida        NOUN      obj
# imposible   ADJ       amod
# el numero de entidades encontradas en 186 frases fue: 108 entidades
#  numero de frases con entidades: 81

# %% [markdown]
# Para hacer un mejor analisis de las frases de agresion del dataset, podemos entrenar un nuevo componente en el pipeline de procesamiento llamado TextCategorizer, que identifica la naturaleza de un texto procesado. En este caso se entrenara el TextCategorizer para que identifique si una frase es o no es amenazante. Este dataset ya contiene una columa que indica la clasificacion de la frase, por lo que podemos usar el dataset para crear training data para entrenar al modelo.
# - En este caso entrenamos un modelo en blanco pero se puede entrenar el TextCategorizer sobre un modelo preexistente.
# - Por el bajo volumen de los datos para el entrenamiento usamos la arquitectura ensemble, que es la mas precisa pero es mas lenta que las demas opciones.
# - tomamos 236 frases del dataset para el entrenamiento del TextCategorizer y las restantes para el testeo.
# - hacemos 25 iteraciones de entrenamiento, y para cada una de ellas mostramos precision, recall y f_score para monitoriar el entrenamiento del modelo.

# %% [markdown]
# En el entrenamiento del modelo para crear la data de entrenamiento llamamos a esta funcion que fue creada en el modulo xl_text. La funcion crea las listas de frases y de categorias de cada una usando la categorizacion ya realizada en el excel

# %%
import openpyxl

def excel_to_data(doc, first_cell_num, last_cell_num, col_phrases, col_cats):
    """ Esta funcion devuelve una lista con todas las frases unicas encontradas en un rango de celdas de un excel
    y una lista con las categorias amenazante, no amenazante para cada una de estas frases.
    doc: string nombre del archivo excel a trabajar.
    first_cell_num: numero de la primera celda del rango a copiar.
    last_cell_num:  numero de la ultima celda del rango a copiar
    col_phrases: columna donde estan las frases en el archivo doc
    col_cats: columna donde esta la clasificacion en el archivo doc
     """
    cat_list = []
    text_list = []
    excel_document = openpyxl.load_workbook(doc, data_only=True)
    first_sheet = excel_document.sheetnames[0]
    sheet = excel_document[first_sheet]
    for i in range(first_cell_num, last_cell_num):
        cell = sheet[col_phrases + str(i)]
        if cell.value and (cell.value != 'no corresponde') :
            text = cell.value.replace('_', ' ')
            if (text not in text_list):
                cat_cell = sheet[col_cats + str(i)]
                if cat_cell.value == 'amenazas':
                    cats = {'AMENAZANTE': 1, 'NO_AMENAZANTE': 0}
                else:
                    cats = {'AMENAZANTE': 0, 'NO_AMENAZANTE': 1}
                cat_list.append(cats)
                text_list.append(text)
    return text_list, cat_list

doc = "set_de_datos_con_perspectiva_de_genero.xlsx"
texts, cats = excel_to_data(doc, 2, 2500, 'S', 'H')
print (len(texts))
# Out:
# 236

# %%
from __future__ import unicode_literals, print_function
import plac
import random
from xl_text import excel_to_data, excel_to_set
from pathlib import Path
import spacy
from spacy.util import minibatch, compounding


def evaluate(tokenizer, textcat, texts, cats):
    docs = (tokenizer(text) for text in texts)
    tp = 0.0  # True positives
    fp = 1e-8  # False positives
    fn = 1e-8  # False negatives
    tn = 0.0  # True negatives
    for i, doc in enumerate(textcat.pipe(docs)):
        gold = cats[i]
        for label, score in doc.cats.items():
            if label not in gold:
                continue
            if label == "NEGATIVE":
                continue
            if score >= 0.5 and gold[label] >= 0.5:
                tp += 1.0
            elif score >= 0.5 and gold[label] < 0.5:
                fp += 1.0
            elif score < 0.5 and gold[label] < 0.5:
                tn += 1
            elif score < 0.5 and gold[label] >= 0.5:
                fn += 1
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    if (precision + recall) == 0:
        f_score = 0.0
    else:
        f_score = 2 * (precision * recall) / (precision + recall)
    return {"textcat_p": precision, "textcat_r": recall, "textcat_f": f_score}


"""model=("Model name. Defaults to blank 'en' model.", "option", "m", str),
    output_dir=("Optional output directory", "option", "o", Path),
    n_iter=("Number of training iterations", "option", "n", int),
    init_tok2vec=("Pretrained tok2vec weights", "option", "t2v", Path),"""

model=None
output_dir=None
n_iter=25
init_tok2vec=None

if output_dir is not None:
    output_dir = Path(output_dir)
    if not output_dir.exists():
        output_dir.mkdir()

if model is not None:
    nlp = spacy.load(model)
    print("Loaded model '%s'" % model)
else:
    nlp = spacy.blank("es")
    print("Created blank 'es' model")

# add the text classifier to the pipeline if it doesn't exist
if "textcat" not in nlp.pipe_names:
    textcat = nlp.create_pipe("textcat", config={"exclusive_classes": True, "architecture": "ensemble"})
    nlp.add_pipe(textcat, last=True)
else:
    textcat = nlp.get_pipe("textcat")

# add labels to text classifier
textcat.add_label("AMENAZANTE")
textcat.add_label("NO_AMENAZANTE")

doc = "set_de_datos_con_perspectiva_de_genero.xlsx"
texts, cats = excel_to_data(doc, 2, 2500, 'S', 'H')
train_texts = texts[:200]
dev_texts = texts[200:]
train_cats = cats[:200]
dev_cats = cats[200:]
train_data = list(zip(train_texts, [{"cats": cats} for cats in train_cats]))
print(f' Using {len(texts)} examples ({len(train_texts)} training, {len(dev_texts)} evaluation)')


# get names of other pipes to disable them during training
pipe_exceptions = ["textcat", "trf_wordpiecer", "trf_tok2vec"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
with nlp.disable_pipes(*other_pipes):
    optimizer = nlp.begin_training()
    if init_tok2vec is not None:
        with init_tok2vec.open("rb") as file_:
            textcat.model.tok2vec.from_bytes(file_.read())
    print("Entrenando el modelo...")
    print("{:^5}\t{:^5}\t{:^5}\t{:^5}".format("LOSS", "P", "R", "F"))
    batch_sizes = compounding(4.0, 32.0, 1.001)
    for i in range(n_iter):
        losses = {}
        random.shuffle(train_data)
        batches = minibatch(train_data, size=batch_sizes)
        for batch in batches:
            texts, annotations = zip(*batch)
            nlp.update(texts, annotations, sgd=optimizer, drop=0.2, losses=losses)
        with textcat.model.use_params(optimizer.averages):
            # evaluate on the dev data
            scores = evaluate(nlp.tokenizer, textcat, dev_texts, dev_cats)
        print(
            "{0:.3f}\t{1:.3f}\t{2:.3f}\t{3:.3f}".format( 
                losses["textcat"],
                scores["textcat_p"],
                scores["textcat_r"],
                scores["textcat_f"],
            )
        )

if output_dir is not None:
    with nlp.use_params(optimizer.averages):
        nlp.to_disk(output_dir)
    print(f"modelo guardado en:{output_dir}")
# Out:
# Created blank 'es' model
#  Using 236 examples (200 training, 36 evaluation)
# Entrenando el modelo...
# LOSS 	  P  	  R  	  F
# 1.425	0.444	0.444	0.444
# 1.176	0.667	0.667	0.667
# 0.960	0.694	0.694	0.694
# 0.855	0.694	0.694	0.694
# 0.437	0.667	0.667	0.667
# 0.345	0.611	0.611	0.611
# 0.297	0.611	0.611	0.611
# 0.208	0.667	0.667	0.667
# 0.185	0.611	0.611	0.611
# 0.087	0.611	0.611	0.611
# 0.089	0.583	0.583	0.583
# 0.053	0.639	0.639	0.639
# 0.065	0.639	0.639	0.639
# 0.042	0.639	0.639	0.639
# 0.034	0.611	0.611	0.611
# 0.023	0.611	0.611	0.611
# 0.036	0.639	0.639	0.639
# 0.031	0.611	0.611	0.611
# 0.027	0.583	0.583	0.583
# 0.017	0.583	0.583	0.583
# 0.026	0.583	0.583	0.583
# 0.013	0.611	0.611	0.611
# 0.013	0.611	0.611	0.611
# 0.010	0.611	0.611	0.611
# 0.013	0.611	0.611	0.611

# %% [markdown]
# Testeamos el modelo entrenado y se observa que se encontraron 96 frases amenazantes de las 147  y la mayoria de los resultados parecen correctos.

# %%
texts = excel_to_set('set_de_datos_con_perspectiva_de_genero.xlsx', first_cell='S2500', last_cell='S3827')
print(f'numero de frases a testear: {len(texts)}')
docs = [nlp(text) for text in texts]
num_amen = 0
for doc in docs:
    print(doc.text, doc.cats)
    if(doc.cats['AMENAZANTE'] > 0.5):
        num_amen += 1
print(f'numero de frases a amenazantes:{num_amen}')
# Out:
# numero de frases a testear: 147
# te voy a perseguir te voy a hacer la vida imposibe {'AMENAZANTE': 0.996906578540802, 'NO_AMENAZANTE': 0.0030934219248592854}
# yo mando aca hija de puta  estos son mis hijos varones y van a hacer lo que yo digo {'AMENAZANTE': 0.9846748113632202, 'NO_AMENAZANTE': 0.015325173735618591}
# sino venis conmigo te vas a morir por coronavirus {'AMENAZANTE': 0.0027013213839381933, 'NO_AMENAZANTE': 0.9972986578941345}
# queres quedarte con negros   no sabes quien soy yo {'AMENAZANTE': 0.006998348981142044, 'NO_AMENAZANTE': 0.9930016398429871}
# puta todo vuelve si no estas conmigo no estas con nadie mejor que te
# escondas. {'AMENAZANTE': 0.6886298656463623, 'NO_AMENAZANTE': 0.31137019395828247}
# gorda lechona vas a vivir toda tu vida asi te falta mucho para bajar de peso {'AMENAZANTE': 0.2322021722793579, 'NO_AMENAZANTE': 0.7677978277206421}
# hija de puta {'AMENAZANTE': 0.9332010746002197, 'NO_AMENAZANTE': 0.06679896265268326}
# estas viva porque yo quiero hija de mil puta me las vas a pagar {'AMENAZANTE': 0.7166052460670471, 'NO_AMENAZANTE': 0.2833947539329529}
# tenes la culpa de no perdonarme   vos no entendes   yo te voy a convertir {'AMENAZANTE': 0.9988019466400146, 'NO_AMENAZANTE': 0.0011981044663116336}
# no te vas a ir quedate aca {'AMENAZANTE': 0.002607273869216442, 'NO_AMENAZANTE': 0.9973926544189453}
# puta de mierda   te voy a hacer desaparecer {'AMENAZANTE': 0.9990361928939819, 'NO_AMENAZANTE': 0.0009638586780056357}
# te voy a cortar no sabes con quien te metes {'AMENAZANTE': 0.999297022819519, 'NO_AMENAZANTE': 0.0007029608241282403}
# te voy a matar a vos y a tu hija {'AMENAZANTE': 0.9565622210502625, 'NO_AMENAZANTE': 0.04343778267502785}
# tenes novio   me das tu numero de telefono {'AMENAZANTE': 0.1740940809249878, 'NO_AMENAZANTE': 0.8259058594703674}
# entregame a la nena   te voy a hacer desaparecer   te voy a matar {'AMENAZANTE': 0.9983909130096436, 'NO_AMENAZANTE': 0.0016091681318357587}
# negra de mierda {'AMENAZANTE': 0.0014252810506150126, 'NO_AMENAZANTE': 0.9985747337341309}
# tu hija se va conmigo   loca   mal cogida {'AMENAZANTE': 0.0006172765279188752, 'NO_AMENAZANTE': 0.999382734298706}
# te voy a acuchillar   ni tu boton antipanico te va a salvar {'AMENAZANTE': 0.9992938041687012, 'NO_AMENAZANTE': 0.000706161605194211}
# sos una mierda   te voy a hacer mierda   vos no tenes a nadie {'AMENAZANTE': 0.9990715980529785, 'NO_AMENAZANTE': 0.0009283698163926601}
# sos una negra de mierda, no voy a
# parar de molestarte hasta que te mudes de aca negra mierda te voy a matar
# y a vos pelado que decis que me la vas a dar anda cagala a palos qué lloras le tenes miedo a esa negra de mierda {'AMENAZANTE': 0.9977819323539734, 'NO_AMENAZANTE': 0.002218123059719801}
# hija de puta te voy a matar {'AMENAZANTE': 0.9982342720031738, 'NO_AMENAZANTE': 0.001765746041201055}
# hija de puta te mato te mato a vos a tu macho y a quien se meta me importa tres huevos la policia no me interesa ir preso {'AMENAZANTE': 0.1270049512386322, 'NO_AMENAZANTE': 0.8729950785636902}
# te voy a prender fuego la casa te voy a sacar a la nena {'AMENAZANTE': 0.9976096153259277, 'NO_AMENAZANTE': 0.0023903422988951206}
# no le cuentes a nadie porque te mato {'AMENAZANTE': 0.39501312375068665, 'NO_AMENAZANTE': 0.6049869060516357}
# hija de puta puta de mierda no te voy a dejar ver mas a tus hijas te voy a sacar todo lo que te di {'AMENAZANTE': 0.008345070295035839, 'NO_AMENAZANTE': 0.9916548728942871}
# sos una hija de puta, te voy a matar {'AMENAZANTE': 0.9977110624313354, 'NO_AMENAZANTE': 0.002288930118083954}
# que  se consiga un buen abogado porque se esta equivocando y pronto voy a salir {'AMENAZANTE': 0.0016716158716008067, 'NO_AMENAZANTE': 0.9983283877372742}
# ahora te voy a dejar yo marcas en la boca  a ver hija de puta estas depilada  a ver si estas dilatada {'AMENAZANTE': 0.9981039762496948, 'NO_AMENAZANTE': 0.0018960338784381747}
# te voy a matar {'AMENAZANTE': 0.9982343912124634, 'NO_AMENAZANTE': 0.001765614841133356}
# si no me dejas entrar por las buenas voy a entrar por las malas {'AMENAZANTE': 0.05487993359565735, 'NO_AMENAZANTE': 0.945120096206665}
# sos una hija de puta te voy a matar {'AMENAZANTE': 0.998200535774231, 'NO_AMENAZANTE': 0.001799417077563703}
# zorra   te voy a grabar para mandar a alguien que te mate   puta   te voy a mandar a matar {'AMENAZANTE': 0.9987800717353821, 'NO_AMENAZANTE': 0.0012199862394481897}
# dame a mi hija te tiro la puerta abajo {'AMENAZANTE': 0.00048180075827986, 'NO_AMENAZANTE': 0.9995181560516357}
# a vos te tengo que matar {'AMENAZANTE': 0.9977743029594421, 'NO_AMENAZANTE': 0.0022257131058722734}
# te voy a quemar la casa si haces la denuncia te mato {'AMENAZANTE': 0.7001627683639526, 'NO_AMENAZANTE': 0.29983723163604736}
# no vas a estar con nadie no te voy a dejar estar con nadie vos sos mia {'AMENAZANTE': 0.001663600211031735, 'NO_AMENAZANTE': 0.9983363747596741}
# puta te voy a matar nadie te va a ver aca estas sola  te voy a tirar y nadie va a saber tienes que estar a mis ordenes {'AMENAZANTE': 0.999146580696106, 'NO_AMENAZANTE': 0.0008533631335012615}
# donde te crees que vas {'AMENAZANTE': 0.7890806198120117, 'NO_AMENAZANTE': 0.21091939508914948}
# concha de tu madre   yo pago aca vos te vas a ir {'AMENAZANTE': 0.0005976215470582247, 'NO_AMENAZANTE': 0.9994024038314819}
# te voy a romper la cabeza   hija de puta   te voy a matar   no me dejas ver a las nenas {'AMENAZANTE': 0.9989416003227234, 'NO_AMENAZANTE': 0.0010584071278572083}
# gorda hija de puta te la vas a ver conmigo {'AMENAZANTE': 0.9992601275444031, 'NO_AMENAZANTE': 0.0007398672751151025}
# te voy a hacer algo que te va a doler {'AMENAZANTE': 0.9986957907676697, 'NO_AMENAZANTE': 0.001304187928326428}
# puta zorra quedate en el molde sino te pego cuatro tiros yo con vos hago lo que quiero {'AMENAZANTE': 0.001674463041126728, 'NO_AMENAZANTE': 0.998325526714325}
# vos sos la segunda {'AMENAZANTE': 0.9984726309776306, 'NO_AMENAZANTE': 0.001527352724224329}
# te voy a matar   te voy a prender fuego la casa   paraguaya de mierda   muerta de hambre {'AMENAZANTE': 0.9930703043937683, 'NO_AMENAZANTE': 0.006929727271199226}
# enviarle una caja de bombones, junto muñeco de peluche y un ramo de flores con
# un manuscrito el cual refería la frase "TE AMO CACHIRULA. Este episodio tiene como
# antecedente una sería de conductas intimatorios perpetradas por XX hacia la víctima
# en el año XX tales corno referirle "que se había enamorado de ella” “que no podia
# pasar una vida sin ella. Es menester hacer mención que luego de que XX le hiciera
# saber su desinterés por mantener un vínculo amoroso al denunciado, éste intento
# quitarse la vida dejando un mensaje por la red social “Facebook" {'AMENAZANTE': 0.007603757083415985, 'NO_AMENAZANTE': 0.9923961758613586}
# vos sos mia {'AMENAZANTE': 0.997812032699585, 'NO_AMENAZANTE': 0.0021879766136407852}
# te voy a reventar la cabeza {'AMENAZANTE': 0.974177896976471, 'NO_AMENAZANTE': 0.025822117924690247}
# por tu culpa estuve detenido toda la noche {'AMENAZANTE': 0.3912544548511505, 'NO_AMENAZANTE': 0.6087455153465271}
# sos una enferma  hija de mil puta   te vas a morir en el infierno {'AMENAZANTE': 0.001400331617332995, 'NO_AMENAZANTE': 0.9985997080802917}
# vos y yo no vamos a salir de aca lo lamento por los chicos vos tenes la culpa de que yo tome y vuelva a consumir {'AMENAZANTE': 0.9718045592308044, 'NO_AMENAZANTE': 0.028195425868034363}
# te voy a hacer quilombo en tu casa y en tu trabajo vieja de mierda   llama a la policia hija de puta te voy a hacer echar del trabajo {'AMENAZANTE': 0.0012643550289794803, 'NO_AMENAZANTE': 0.9987356066703796}
# anda puta de mierda, porque no le pedías plata a tus machos {'AMENAZANTE': 0.9681847095489502, 'NO_AMENAZANTE': 0.03181523084640503}
# hija de puta   puta de mierda   no te salva ni tu mama {'AMENAZANTE': 0.9314009547233582, 'NO_AMENAZANTE': 0.06859897822141647}
# puta de mierda   te voy a matar ni la denuncia te va a salvar {'AMENAZANTE': 0.9993017911911011, 'NO_AMENAZANTE': 0.0006982230697758496}
# despues no quiero reclamos {'AMENAZANTE': 0.0011354106245562434, 'NO_AMENAZANTE': 0.9988646507263184}
# te voy a matar   levanta la causa sino te voy a matar {'AMENAZANTE': 0.9981624484062195, 'NO_AMENAZANTE': 0.0018375542713329196}
# te voy a matar sos una hija de puta me pusiste la perimetral te voy a reventar {'AMENAZANTE': 0.9986525177955627, 'NO_AMENAZANTE': 0.0013474596198648214}
# sos una puta estabas con tus machos donde fuiste por que no llegaste a casa {'AMENAZANTE': 0.06010378524661064, 'NO_AMENAZANTE': 0.939896285533905}
# yo tengo derecho de ver a mi hijo nadie me puede decir nada me voy a olvidar que soy policia {'AMENAZANTE': 0.9754274487495422, 'NO_AMENAZANTE': 0.02457250840961933}
# necesito hablar con vos no quiero pelear mas puta de mierda seguro tenes otro macho te voy a matar a vos y al macho que tengas en serio llamaste a la policia si no te hice nada {'AMENAZANTE': 0.0012372907949611545, 'NO_AMENAZANTE': 0.9987627267837524}
# puta lesbiana te fuiste con tus amigas si te veo con otro te voy a cagar apalos {'AMENAZANTE': 0.9871441721916199, 'NO_AMENAZANTE': 0.012855781242251396}
# hija de puta te voy a matar voy a volver y te voy a cortar en pedacitos {'AMENAZANTE': 0.9991759657859802, 'NO_AMENAZANTE': 0.0008240120369009674}
# te voy a cagar a trompadas {'AMENAZANTE': 0.9937508702278137, 'NO_AMENAZANTE': 0.006249101832509041}
# sos una trola puta  vos te sacas las ganas con tus compañeros del colegio  por eso no queres estar conmigo {'AMENAZANTE': 0.1771710216999054, 'NO_AMENAZANTE': 0.8228289484977722}
# quiero a mis hijos ya te voy a hacer la vida imposible tengo que contarle a tu jefe lo que hiciste en trabajos anteriores {'AMENAZANTE': 0.0027132185641676188, 'NO_AMENAZANTE': 0.9972867965698242}
# hija de puta   te voy a matar {'AMENAZANTE': 0.9982337951660156, 'NO_AMENAZANTE': 0.0017662066966295242}
# deci la verdad sino sabes lo que te va a pasar {'AMENAZANTE': 0.9986924529075623, 'NO_AMENAZANTE': 0.0013076015748083591}
# no te hagas la viva que sabemos tus horarios y que vivis aca   te hago un monton de hijos   te parto en ocho   ya te voy a agarrar   te voy a hacer mierda {'AMENAZANTE': 0.0006354537326842546, 'NO_AMENAZANTE': 0.9993645548820496}
# si a mi me pasa algo donde te vea te puedo hacer algo {'AMENAZANTE': 0.0800085961818695, 'NO_AMENAZANTE': 0.9199914336204529}
# sos una desgraciada   maldita   yo te quiero pero a vos te voy a castigar {'AMENAZANTE': 0.9966506361961365, 'NO_AMENAZANTE': 0.0033493980299681425}
# sos una puta   me la vas a pagar   te voy a matar   estas con otro {'AMENAZANTE': 0.9991287589073181, 'NO_AMENAZANTE': 0.0008712257258594036}
# te vamos a matar a tu hija {'AMENAZANTE': 0.0024757205974310637, 'NO_AMENAZANTE': 0.9975243210792542}
# vas a sufrir hoy voy a buscarte te pongo un tiro {'AMENAZANTE': 0.9650421738624573, 'NO_AMENAZANTE': 0.03495785966515541}
# voy a hacer algo que te va a doler, porque yo a vos te voy a matar y a el tambien yo te voy a
# encontrar y me las vas a pagar yo le voy a matar toda su familia, este con
# vos o no esté con vos, mudate a donde sea, yo te voy a encontrar puta te voy a prender fuego a ella, a su familia, que la iba a matar, y que no se le ocurriera aparecer porque no la contaba traeme al nene, mas vale que lo traigas, los voy a matar a todos, no me hagas poner loco, los voy a matar a todos {'AMENAZANTE': 0.25669828057289124, 'NO_AMENAZANTE': 0.7433016896247864}
# pudiendo matar a tu hija no
# lo hago pero ganas no me faltan  no entiende por qué me dejo y está con otro tipo”  {'AMENAZANTE': 0.01739567145705223, 'NO_AMENAZANTE': 0.9826043248176575}
# te voy a matar   hija de puta {'AMENAZANTE': 0.9684929847717285, 'NO_AMENAZANTE': 0.031507041305303574}
# si volves a denunciarme te voy a pegar un tiro {'AMENAZANTE': 0.999403715133667, 'NO_AMENAZANTE': 0.0005962876020930707}
# ahora se va a terminar todo   se que andas con el {'AMENAZANTE': 0.9985882639884949, 'NO_AMENAZANTE': 0.001411713776178658}
# te voy a mandar al hospital   te voy a reventar las rodillas {'AMENAZANTE': 0.9992192983627319, 'NO_AMENAZANTE': 0.000780695874709636}
# te fuiste con tus machos eres una puta  ahora vas a ver te voy a matar {'AMENAZANTE': 0.9993540644645691, 'NO_AMENAZANTE': 0.0006459570140577853}
# hija de puta vos te mereces que te pegue {'AMENAZANTE': 0.9945785999298096, 'NO_AMENAZANTE': 0.005421353038400412}
# me mato o te mato {'AMENAZANTE': 0.9929429888725281, 'NO_AMENAZANTE': 0.007056924980133772}
# no te rompo la cara porque estan los nenes {'AMENAZANTE': 0.9961282014846802, 'NO_AMENAZANTE': 0.003871808759868145}
# te voy a reventar {'AMENAZANTE': 0.03302525728940964, 'NO_AMENAZANTE': 0.966974675655365}
# vos sin mi no podes vivir  infeliz  donde estabas {'AMENAZANTE': 0.003035121364519, 'NO_AMENAZANTE': 0.9969648718833923}
# te voy a matar  hija de puta  te voy a cagar a piñas {'AMENAZANTE': 0.9288828372955322, 'NO_AMENAZANTE': 0.07111712545156479}
# puta de mierda, vos seguro estas con mi sobrino  vos le abris las piernas a cualquiera {'AMENAZANTE': 0.9955664277076721, 'NO_AMENAZANTE': 0.004433596972376108}
# no vas a subir mas te voy a meter presa hacete coger para que te paguen cinco mil para las zapatillas de tu nene {'AMENAZANTE': 0.024840088561177254, 'NO_AMENAZANTE': 0.9751598834991455}
# puta de mierda   te voy a matar {'AMENAZANTE': 0.9982328414916992, 'NO_AMENAZANTE': 0.0017671535024419427}
# queres chuparme la pija   te voy a violar   no camines sola {'AMENAZANTE': 0.9639899730682373, 'NO_AMENAZANTE': 0.03600999340415001}
# trola   puta   con razon tu familia no te quiere   hija de puta   me voy a suicidar   es tu culpa {'AMENAZANTE': 0.9914652705192566, 'NO_AMENAZANTE': 0.008534746244549751}
# puta de mierda {'AMENAZANTE': 0.0015545898349955678, 'NO_AMENAZANTE': 0.998445451259613}
# porque sos asi no eras asi   te voy a sacar a los chicos  vos te vas con el   lo voy a matar a el   te voy a matar {'AMENAZANTE': 0.9980217218399048, 'NO_AMENAZANTE': 0.0019783219322562218}
# andate a la concha de tu madre, hija de puta  ya te voy a enganchar asi como vos me estas cagando la vida yo te la voy a cagar a vos y te voy a pegar donde mas te duele te voy a matar la concha bien de tu madre te voy a pegar donde mas te duele ya te voy a enganchar y te voy a cagar a palos no me importa nada si no estas conmigo me mato {'AMENAZANTE': 0.9965105652809143, 'NO_AMENAZANTE': 0.0034894845448434353}
# tu vas a estar bien muerta te voy a arruinar te voy a matar {'AMENAZANTE': 0.9993035793304443, 'NO_AMENAZANTE': 0.00069642678136006}
# yo voy a venir las veces que quiera porque tambien es mi casa {'AMENAZANTE': 0.002263221424072981, 'NO_AMENAZANTE': 0.9977368116378784}
# hija de puta   me estas cagando   vas a ver lo que te va a pasar   no tengo nada que perder   nadie te va a poder salvar {'AMENAZANTE': 0.9991514682769775, 'NO_AMENAZANTE': 0.0008485232829116285}
# puta perra {'AMENAZANTE': 0.09024183452129364, 'NO_AMENAZANTE': 0.9097581505775452}
# te voy a romper la cabeza   tenes que irte de esta casa   te voy a matar {'AMENAZANTE': 0.998764157295227, 'NO_AMENAZANTE': 0.0012358350213617086}
# te voy a matar   sos una puta {'AMENAZANTE': 0.9984839558601379, 'NO_AMENAZANTE': 0.0015161017654463649}
# te voy a hacer quilombo en tu casa y en tu trabajo   vieja de mierda   llama a la policia hija de puta   te voy a hacer echar del trabajo {'AMENAZANTE': 0.0013004656648263335, 'NO_AMENAZANTE': 0.9986995458602905}
# la concha de tu madre donde estas la concha de tu madre te mato perra {'AMENAZANTE': 0.05403362214565277, 'NO_AMENAZANTE': 0.9459664225578308}
# “Hola hermosa, ¿Querés chuparme la pija?", “Este viejo pajero te va a pegar alta cogida, alta violada"-, "Ya te voy agarrar sola, te voy a violar y te voy a cagar a palos", "No camines sola", 'Dale llama a la policía, delante de ellos me vas hacer una paja”. {'AMENAZANTE': 0.9977079629898071, 'NO_AMENAZANTE': 0.002292032353579998}
# pendeja de mierda vos no te tenes que meter sos una cualquiera como tu mama {'AMENAZANTE': 0.8454282283782959, 'NO_AMENAZANTE': 0.15457169711589813}
# hija de puta callate vieja de mierda te voy a romper la cabeza  es mi casa yo hago lo que quiero hija de puta muerta de hambre te voy a romper la cabeza te voy a dar golpes te voy a prender fuego {'AMENAZANTE': 0.9670767188072205, 'NO_AMENAZANTE': 0.03292332589626312}
# puta hija de puta conchuda {'AMENAZANTE': 0.9147879481315613, 'NO_AMENAZANTE': 0.08521204441785812}
# mentirosa   nunca te pegue   fuiste vos   me denunciaste   ya van a ver quien soy   se las voy a dar {'AMENAZANTE': 0.9989998936653137, 'NO_AMENAZANTE': 0.001000087009742856}
# vos y yo no vamos a salir de aca lo lamento por los chicos   vos tenes la culpa de que yo tome y vuelva a consumir {'AMENAZANTE': 0.9718027114868164, 'NO_AMENAZANTE': 0.02819724753499031}
# soy un loco de mierda   te voy a matar   voy a pasar en cana toda mi vida pero a ese hijo de puta lo voy a matar   hija de re mil puta {'AMENAZANTE': 0.9983137845993042, 'NO_AMENAZANTE': 0.0016862577758729458}
# te va a ir muy mal todo lo que estas haciendo lo vas a pagar tu familia es una mierda te van a garchar te van a coger la vas a pagar muy caro odio a tu familia toda tu familia intento separarnos tengo un arma en la casa de mi mama te voy a matar {'AMENAZANTE': 0.9855614304542542, 'NO_AMENAZANTE': 0.014438525773584843}
# queres quedarte con negros {'AMENAZANTE': 0.0044984351843595505, 'NO_AMENAZANTE': 0.9955015778541565}
# subí al auto que te voy a matar {'AMENAZANTE': 0.9981075525283813, 'NO_AMENAZANTE': 0.0018924159230664372}
# puta lesbiana te fuiste con tus amigas si te veo con otro te voy a cagar a palos {'AMENAZANTE': 0.9983367919921875, 'NO_AMENAZANTE': 0.0016631908947601914}
# no me rompas las pelotas porque me voy a ir {'AMENAZANTE': 0.31920626759529114, 'NO_AMENAZANTE': 0.6807937622070312}
# las voy a matar {'AMENAZANTE': 0.9982776641845703, 'NO_AMENAZANTE': 0.0017223893664777279}
# puta prostituta te voy a matar {'AMENAZANTE': 0.9982336759567261, 'NO_AMENAZANTE': 0.0017662594327703118}
# sos una enferma de mierda hija de puta {'AMENAZANTE': 0.003481534542515874, 'NO_AMENAZANTE': 0.9965184926986694}
# zorra   te voy a garcar para mandar a alguien que te mate   puta   te voy a mandar a matar {'AMENAZANTE': 0.9922609925270081, 'NO_AMENAZANTE': 0.007739041466265917}
# voy a pagar para que te maten no me voy a ensuciar las manos {'AMENAZANTE': 0.9984883069992065, 'NO_AMENAZANTE': 0.001511695678345859}
# te recuerdo que todos los chongos con los que estuviste y a donde saliste lo hiciste con plata mia porque la sube te la pagaba yo {'AMENAZANTE': 0.00037586831604130566, 'NO_AMENAZANTE': 0.9996241331100464}
# bajate hija de puta {'AMENAZANTE': 0.0004816207801923156, 'NO_AMENAZANTE': 0.9995183944702148}
# yo te voy a encontrar y te voy a pegar un tiro nos vemos o te busco te mato y listo {'AMENAZANTE': 0.9986312985420227, 'NO_AMENAZANTE': 0.0013686579186469316}
# voy a pagar para que te maten {'AMENAZANTE': 0.9985553622245789, 'NO_AMENAZANTE': 0.0014446319546550512}
# te voy a quemar la casa   si haces la denuncia te mato   te voy a matar a vos y a tus hijos {'AMENAZANTE': 0.9979612827301025, 'NO_AMENAZANTE': 0.0020387512631714344}
# me estas provocando   queres que te cague a trompadas   vos buscas que yo te cague a piñas {'AMENAZANTE': 0.9971690773963928, 'NO_AMENAZANTE': 0.0028309894260019064}
# sos una puta no me hagas enojar te voy a matar {'AMENAZANTE': 0.997954249382019, 'NO_AMENAZANTE': 0.0020456966012716293}
# ahora te voy a dejar yo marcas en la boca a ver hija de puta estas depilada ahora te va a doler hija de puta a esa hija de puta ya la voy a agarrar, sé como tengo que hacer, tiempo al tiempo {'AMENAZANTE': 0.991304874420166, 'NO_AMENAZANTE': 0.008695092983543873}
# los voy a matar a todos {'AMENAZANTE': 0.9939019680023193, 'NO_AMENAZANTE': 0.0060980068519711494}
# yo a vos te pago en cana  antes de ir preso por amenazas prefiero ir preso por femicidio {'AMENAZANTE': 0.227144256234169, 'NO_AMENAZANTE': 0.7728557586669922}
# no denuncies  sabes lo que se te viene {'AMENAZANTE': 0.0242864191532135, 'NO_AMENAZANTE': 0.9757136106491089}
# esta quiere que me vaya quiere traer a sus machos {'AMENAZANTE': 0.0011689728125929832, 'NO_AMENAZANTE': 0.9988309741020203}
# te amo   solo vos y yo   que no te calienten la cabeza {'AMENAZANTE': 0.9708936810493469, 'NO_AMENAZANTE': 0.029106291010975838}
# estupida tarada yo te lo prometo que te hago la vida imposible {'AMENAZANTE': 0.043456826359033585, 'NO_AMENAZANTE': 0.9565431475639343}
# hija de puta   por culpa tuya estoy en la calle {'AMENAZANTE': 0.968377947807312, 'NO_AMENAZANTE': 0.03162207081913948}
# hija de puta te voy a matar te voy a cortar en pedacitos {'AMENAZANTE': 0.9991074204444885, 'NO_AMENAZANTE': 0.0008924994035623968}
# hija de puta  te vas a arrepentir toda tu vida  te vas a arrepentir asi son ustedes que inventan  asi son ustedes {'AMENAZANTE': 0.9995095729827881, 'NO_AMENAZANTE': 0.0004903817316517234}
# haganse cargo de esta mujer No te hagas la viva yéndote temprano del trabajo Yo se donde vivís y se todo tu recorrido {'AMENAZANTE': 0.004083461593836546, 'NO_AMENAZANTE': 0.9959165453910828}
# no vas a estar con nadie  no te voy a dejar estar con nadie vos sos mia {'AMENAZANTE': 0.0016637634253129363, 'NO_AMENAZANTE': 0.9983362555503845}
# pelotudo inutil de mierda no servis para nada {'AMENAZANTE': 0.18139678239822388, 'NO_AMENAZANTE': 0.8186032176017761}
# puta sucia {'AMENAZANTE': 0.3658490478992462, 'NO_AMENAZANTE': 0.6341509222984314}
# sos una puta   sos una trola que no sirve para nada {'AMENAZANTE': 0.5630446076393127, 'NO_AMENAZANTE': 0.43695542216300964}
# de aca viva no salis {'AMENAZANTE': 0.977946400642395, 'NO_AMENAZANTE': 0.022053634747862816}
# te voy a matar en la cama de quien dormis ahora  cerra la boca porque te va a ir mal {'AMENAZANTE': 0.9975578784942627, 'NO_AMENAZANTE': 0.0024421564303338528}
# puta {'AMENAZANTE': 0.8031591773033142, 'NO_AMENAZANTE': 0.1968408077955246}
# te voy a matar a vos voy a matar al negro de mierda ese que tenes con vos  hija de puta {'AMENAZANTE': 0.9891926646232605, 'NO_AMENAZANTE': 0.010807360522449017}
# hija de puta   vos te mereces que te pegue {'AMENAZANTE': 0.9945683479309082, 'NO_AMENAZANTE': 0.005431678611785173}
# numero de frases a amenazantes:96

# %% [markdown]
# Otra opcion es entrenar un modelo con la totalidad de las frases que se encuentran en el dataset, ya que todas estas ya se encuentran clasificadas, y guardar el modelo para utilizarlo con otros textos.
